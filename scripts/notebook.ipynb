# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '05 Multiple Minima'))

# %%
import py_10_multiple_minima as py10
importlib.reload(py10)
py10.main()
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded ^GSPC from 2010-01-04 to 2025-11-25 (N=4000, log=True).
# Train length = 2400, val = 800, test = 800.
#
# === Building spectral solver for d=1 ===
#
# === Building spectral solver for d=2 ===
#
# === Building spectral solver for d=3 ===
#
# === Building spectral solver for d=4 ===
#
# === Finding all local minima in s for d=1 ===
#
# [d=1] found 2 local minima on [0.001,0.999]:
#   s≈0.809593, J(s)≈1.261403e-02
#   s≈0.999000, J(s)≈1.157913e-02
# === Finding all local minima in s for d=2 ===
#
# [d=2] found 4 local minima on [0.001,0.999]:
#   s≈0.882066, J(s)≈8.493136e-03
#   s≈0.985516, J(s)≈2.210094e-02
#   s≈0.994469, J(s)≈8.538821e-03
#   s≈0.998917, J(s)≈2.006105e-02
# === Finding all local minima in s for d=3 ===
#
# [d=3] found 5 local minima on [0.001,0.999]:
#   s≈0.001000, J(s)≈2.135399e+05
#   s≈0.920089, J(s)≈1.727146e+02
#   s≈0.960556, J(s)≈3.489835e-01
#   s≈0.989548, J(s)≈1.170477e-02
#   s≈0.997193, J(s)≈1.108568e-01
# === Finding all local minima in s for d=4 ===
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:113: RuntimeWarning: divide by zero encountered in divide
#   trAinv = np.sum(1.0 / denom)
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:174: RuntimeWarning: divide by zero encountered in divide
#   z = y / denom                               # elementwise
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:175: RuntimeWarning: invalid value encountered in matmul
#   t_hat = Q @ z                               # back to original basis
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:177: RuntimeWarning: invalid value encountered in matmul
#   m_new = float(np.mean(K @ t_hat))
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:184: RuntimeWarning: divide by zero encountered in divide
#   alpha = 1.0 / (1.0 + lam * eigvals)
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:186: RuntimeWarning: invalid value encountered in matmul
#   diag_Ainv = (Q ** 2) @ alpha
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:174: RuntimeWarning: overflow encountered in divide
#   z = y / denom                               # elementwise
# [d=4] found 5 local minima on [0.001,0.999]:
#   s≈0.001000, J(s)≈3.157119e+06
#   s≈0.479330, J(s)≈2.602413e+04
#   s≈0.929805, J(s)≈1.331620e+05
#   s≈0.970090, J(s)≈3.315006e+00
#   s≈0.987087, J(s)≈2.936239e+03
# --- Plotting train/val/test for d=1, local minimum 1/2, s≈0.8096, val_MSE≈1.261403e-02 ---
# --- Plotting train/val/test for d=1, local minimum 2/2, s≈0.9990, val_MSE≈1.157913e-02 ---
# --- Plotting train/val/test for d=2, local minimum 1/4, s≈0.8821, val_MSE≈8.493136e-03 ---
# --- Plotting train/val/test for d=2, local minimum 2/4, s≈0.9855, val_MSE≈2.210094e-02 ---
# --- Plotting train/val/test for d=2, local minimum 3/4, s≈0.9945, val_MSE≈8.538821e-03 ---
# --- Plotting train/val/test for d=2, local minimum 4/4, s≈0.9989, val_MSE≈2.006105e-02 ---
# --- Plotting train/val/test for d=3, local minimum 1/5, s≈0.0010, val_MSE≈2.135399e+05 ---
# --- Plotting train/val/test for d=3, local minimum 2/5, s≈0.9201, val_MSE≈1.727146e+02 ---
# --- Plotting train/val/test for d=3, local minimum 3/5, s≈0.9606, val_MSE≈3.489835e-01 ---
# --- Plotting train/val/test for d=3, local minimum 4/5, s≈0.9895, val_MSE≈1.170477e-02 ---
# --- Plotting train/val/test for d=3, local minimum 5/5, s≈0.9972, val_MSE≈1.108568e-01 ---
# --- Plotting train/val/test for d=4, local minimum 1/5, s≈0.0010, val_MSE≈3.157119e+06 ---
# --- Plotting train/val/test for d=4, local minimum 2/5, s≈0.4793, val_MSE≈2.602413e+04 ---
# --- Plotting train/val/test for d=4, local minimum 3/5, s≈0.9298, val_MSE≈1.331620e+05 ---
# --- Plotting train/val/test for d=4, local minimum 4/5, s≈0.9701, val_MSE≈3.315006e+00 ---
# --- Plotting train/val/test for d=4, local minimum 5/5, s≈0.9871, val_MSE≈2.936239e+03 ---
