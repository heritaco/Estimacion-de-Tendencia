# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="NVDA", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[2])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded NVDA from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=2 ===
#
# === Analyzing objectives & local minima for d=2 ===
#
# [d=2] TRAIN minima:
#   s≈0.001000, J_train≈6.784042e+01, RMSE_train≈8.2365, RMSE_val≈0.6180, RMSE_test≈3.4521, RMSE_train_and_val≈7.1401, RMSE_Weighted_train≈4.8484, RMSE_Weighted_val≈0.7417, RMSE_Weighted_test≈4.1398, RMSE_Weighted_train_and_val≈3.6612
#   s≈0.883540, J_train≈3.069073e+00, RMSE_train≈1.7519, RMSE_val≈2.8044, RMSE_test≈10.1103, RMSE_train_and_val≈2.0658, RMSE_Weighted_train≈1.7930, RMSE_Weighted_val≈3.5622, RMSE_Weighted_test≈11.4330, RMSE_Weighted_train_and_val≈2.3558
#   s≈0.971872, J_train≈7.988910e-01, RMSE_train≈0.8938, RMSE_val≈0.9045, RMSE_test≈3.6869, RMSE_train_and_val≈0.8965, RMSE_Weighted_train≈0.8728, RMSE_Weighted_val≈1.1959, RMSE_Weighted_test≈4.1528, RMSE_Weighted_train_and_val≈0.9082
#   s≈0.999000, J_train≈1.545368e+00, RMSE_train≈1.2431, RMSE_val≈0.3272, RMSE_test≈0.4205, RMSE_train_and_val≈1.0890, RMSE_Weighted_train≈0.9974, RMSE_Weighted_val≈0.3351, RMSE_Weighted_test≈0.2878, RMSE_Weighted_train_and_val≈0.7791
# [d=2] VAL minima:
#   s≈0.118635, J_val≈3.800452e-02, RMSE_train≈9.0611, RMSE_val≈0.1949, RMSE_test≈1.7679, RMSE_train_and_val≈7.8482, RMSE_Weighted_train≈5.5175, RMSE_Weighted_val≈0.2330, RMSE_Weighted_test≈2.1807, RMSE_Weighted_train_and_val≈4.1409
#   s≈0.630712, J_val≈2.207564e+00, RMSE_train≈6.2997, RMSE_val≈1.4858, RMSE_test≈4.0847, RMSE_train_and_val≈5.5064, RMSE_Weighted_train≈4.3185, RMSE_Weighted_val≈1.8836, RMSE_Weighted_test≈4.3833, RMSE_Weighted_train_and_val≈3.3975
#   s≈0.925665, J_val≈4.733267e+00, RMSE_train≈2.6803, RMSE_val≈2.1756, RMSE_test≈8.4581, RMSE_train_and_val≈2.5635, RMSE_Weighted_train≈1.6037, RMSE_Weighted_val≈2.7906, RMSE_Weighted_test≈9.6174, RMSE_Weighted_train_and_val≈1.9256
#   s≈0.975504, J_val≈1.221232e-01, RMSE_train≈1.2242, RMSE_val≈0.3495, RMSE_test≈1.0967, RMSE_train_and_val≈1.0745, RMSE_Weighted_train≈0.8899, RMSE_Weighted_val≈0.4194, RMSE_Weighted_test≈1.2253, RMSE_Weighted_train_and_val≈0.7088
#   s≈0.990943, J_val≈1.279552e+00, RMSE_train≈3.8146, RMSE_val≈1.1312, RMSE_test≈1.8847, RMSE_train_and_val≈3.3518, RMSE_Weighted_train≈2.6021, RMSE_Weighted_val≈1.2913, RMSE_Weighted_test≈2.0632, RMSE_Weighted_train_and_val≈2.0961
#   s≈0.998943, J_val≈9.209662e-02, RMSE_train≈1.3407, RMSE_val≈0.3035, RMSE_test≈0.3489, RMSE_train_and_val≈1.1710, RMSE_Weighted_train≈1.0715, RMSE_Weighted_val≈0.3019, RMSE_Weighted_test≈0.2737, RMSE_Weighted_train_and_val≈0.8284
# [d=2] BOTH minima:
#   s≈0.001000, J_both≈5.098107e+01, RMSE_train≈8.2365, RMSE_val≈0.6180, RMSE_test≈3.4521, RMSE_train_and_val≈7.1401, RMSE_Weighted_train≈4.8484, RMSE_Weighted_val≈0.7417, RMSE_Weighted_test≈4.1398, RMSE_Weighted_train_and_val≈3.6612
#   s≈0.887358, J_both≈4.216457e+00, RMSE_train≈1.7711, RMSE_val≈2.7307, RMSE_test≈9.9233, RMSE_train_and_val≈2.0534, RMSE_Weighted_train≈1.7069, RMSE_Weighted_val≈3.4720, RMSE_Weighted_test≈11.2285, RMSE_Weighted_train_and_val≈2.2777
#   s≈0.972872, J_both≈7.576742e-01, RMSE_train≈0.9182, RMSE_val≈0.7081, RMSE_test≈3.0019, RMSE_train_and_val≈0.8704, RMSE_Weighted_train≈0.8145, RMSE_Weighted_val≈0.9468, RMSE_Weighted_test≈3.3797, RMSE_Weighted_train_and_val≈0.7857
#   s≈0.999000, J_both≈1.185902e+00, RMSE_train≈1.2431, RMSE_val≈0.3272, RMSE_test≈0.4205, RMSE_train_and_val≈1.0890, RMSE_Weighted_train≈0.9974, RMSE_Weighted_val≈0.3351, RMSE_Weighted_test≈0.2878, RMSE_Weighted_train_and_val≈0.7791
# [d=2] VAL-WEIGHTED minima:
#   s≈0.115554, J_val_w≈5.389689e-02, RMSE_train≈9.0419, RMSE_val≈0.1956, RMSE_test≈1.8121, RMSE_train_and_val≈7.8315, RMSE_Weighted_train≈5.5012, RMSE_Weighted_val≈0.2322, RMSE_Weighted_test≈2.2342, RMSE_Weighted_train_and_val≈4.1287
#   s≈0.628323, J_val_w≈3.547359e+00, RMSE_train≈6.3545, RMSE_val≈1.4859, RMSE_test≈4.0723, RMSE_train_and_val≈5.5533, RMSE_Weighted_train≈4.3511, RMSE_Weighted_val≈1.8834, RMSE_Weighted_test≈4.3673, RMSE_Weighted_train_and_val≈3.4208
#   s≈0.925689, J_val_w≈7.787519e+00, RMSE_train≈2.6802, RMSE_val≈2.1756, RMSE_test≈8.4581, RMSE_train_and_val≈2.5634, RMSE_Weighted_train≈1.6036, RMSE_Weighted_val≈2.7906, RMSE_Weighted_test≈9.6174, RMSE_Weighted_train_and_val≈1.9256
#   s≈0.975816, J_val_w≈1.671907e-01, RMSE_train≈1.2803, RMSE_val≈0.3575, RMSE_test≈0.8713, RMSE_train_and_val≈1.1231, RMSE_Weighted_train≈0.9234, RMSE_Weighted_val≈0.4089, RMSE_Weighted_test≈0.9680, RMSE_Weighted_train_and_val≈0.7336
#   s≈0.990968, J_val_w≈1.667258e+00, RMSE_train≈3.8196, RMSE_val≈1.1312, RMSE_test≈1.8830, RMSE_train_and_val≈3.3561, RMSE_Weighted_train≈2.6051, RMSE_Weighted_val≈1.2912, RMSE_Weighted_test≈2.0611, RMSE_Weighted_train_and_val≈2.0982
#   s≈0.998944, J_val_w≈9.113167e-02, RMSE_train≈1.3402, RMSE_val≈0.3035, RMSE_test≈0.3486, RMSE_train_and_val≈1.1706, RMSE_Weighted_train≈1.0711, RMSE_Weighted_val≈0.3019, RMSE_Weighted_test≈0.2728, RMSE_Weighted_train_and_val≈0.8281
# [d=2] BOTH-WEIGHTED minima:
#   s≈0.001000, J_both_w≈1.340416e+01, RMSE_train≈8.2365, RMSE_val≈0.6180, RMSE_test≈3.4521, RMSE_train_and_val≈7.1401, RMSE_Weighted_train≈4.8484, RMSE_Weighted_val≈0.7417, RMSE_Weighted_test≈4.1398, RMSE_Weighted_train_and_val≈3.6612
#   s≈0.722539, J_both_w≈7.988798e+00, RMSE_train≈4.4373, RMSE_val≈1.8774, RMSE_test≈5.8697, RMSE_train_and_val≈3.9559, RMSE_Weighted_train≈3.3495, RMSE_Weighted_val≈2.3824, RMSE_Weighted_test≈6.4799, RMSE_Weighted_train_and_val≈2.8264
#   s≈0.928555, J_both_w≈3.703296e+00, RMSE_train≈2.6516, RMSE_val≈2.1813, RMSE_test≈8.4687, RMSE_train_and_val≈2.5423, RMSE_Weighted_train≈1.5945, RMSE_Weighted_val≈2.7975, RMSE_Weighted_test≈9.6283, RMSE_Weighted_train_and_val≈1.9244
#   s≈0.974639, J_both_w≈4.611312e-01, RMSE_train≈1.0880, RMSE_val≈0.4062, RMSE_test≈1.7300, RMSE_train_and_val≈0.9639, RMSE_Weighted_train≈0.8231, RMSE_Weighted_val≈0.5375, RMSE_Weighted_test≈1.9434, RMSE_Weighted_train_and_val≈0.6791
#   s≈0.999000, J_both_w≈6.069500e-01, RMSE_train≈1.2431, RMSE_val≈0.3272, RMSE_test≈0.4205, RMSE_train_and_val≈1.0890, RMSE_Weighted_train≈0.9974, RMSE_Weighted_val≈0.3351, RMSE_Weighted_test≈0.2878, RMSE_Weighted_train_and_val≈0.7791
# --- Plotting train/val/test for d=2, val minimum 1/6, s≈0.1186, MSE≈3.800452e-02 ---
# --- Plotting train/val/test for d=2, val minimum 2/6, s≈0.6307, MSE≈2.207564e+00 ---
# --- Plotting train/val/test for d=2, val minimum 3/6, s≈0.9257, MSE≈4.733267e+00 ---
# --- Plotting train/val/test for d=2, val minimum 4/6, s≈0.9755, MSE≈1.221232e-01 ---
# --- Plotting train/val/test for d=2, val minimum 5/6, s≈0.9909, MSE≈1.279552e+00 ---
# --- Plotting train/val/test for d=2, val minimum 6/6, s≈0.9989, MSE≈9.209662e-02 ---
# --- Plotting train/val/test for d=2, val_w minimum 1/6, s≈0.1156, MSE≈5.389689e-02 ---
# --- Plotting train/val/test for d=2, val_w minimum 2/6, s≈0.6283, MSE≈3.547359e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 3/6, s≈0.9257, MSE≈7.787519e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 4/6, s≈0.9758, MSE≈1.671907e-01 ---
# --- Plotting train/val/test for d=2, val_w minimum 5/6, s≈0.9910, MSE≈1.667258e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 6/6, s≈0.9989, MSE≈9.113167e-02 ---
# --- Plotting train/val/test for d=2, both minimum 1/4, s≈0.0010, MSE≈5.098107e+01 ---
# --- Plotting train/val/test for d=2, both minimum 2/4, s≈0.8874, MSE≈4.216457e+00 ---
# --- Plotting train/val/test for d=2, both minimum 3/4, s≈0.9729, MSE≈7.576742e-01 ---
# --- Plotting train/val/test for d=2, both minimum 4/4, s≈0.9990, MSE≈1.185902e+00 ---
# --- Plotting train/val/test for d=2, both_w minimum 1/5, s≈0.0010, MSE≈1.340416e+01 ---
# --- Plotting train/val/test for d=2, both_w minimum 2/5, s≈0.7225, MSE≈7.988798e+00 ---
# --- Plotting train/val/test for d=2, both_w minimum 3/5, s≈0.9286, MSE≈3.703296e+00 ---
# --- Plotting train/val/test for d=2, both_w minimum 4/5, s≈0.9746, MSE≈4.611312e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 5/5, s≈0.9990, MSE≈6.069500e-01 ---
# --- Plotting train/val/test for d=2, train minimum 1/4, s≈0.0010, MSE≈6.784042e+01 ---
# --- Plotting train/val/test for d=2, train minimum 2/4, s≈0.8835, MSE≈3.069073e+00 ---
# --- Plotting train/val/test for d=2, train minimum 3/4, s≈0.9719, MSE≈7.988910e-01 ---
# --- Plotting train/val/test for d=2, train minimum 4/4, s≈0.9990, MSE≈1.545368e+00 ---
