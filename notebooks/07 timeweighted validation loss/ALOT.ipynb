# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
tickers = ["AAPL", "^MXX", "MSFT", "GOOGL", "AMZN", "TSLA", "META", "NVDA", "JPM", "V", "DIS", "NFLX", "PYPL", "ADBE", "CMCSA", "PFE", "INTC", "CSCO", "PEP", "KO", "NKE", "XOM", "CVX", "BA", "WMT", "T", "VZ", "COST", "MCD", "SBUX", "IBM", "ORCL", "QCOM", "TXN", "AVGO", "AMD", "INTU", "MDLZ", "AMAT", "LRCX", "MU", "ADI", "SNPS", "XLNX", "SWKS", "KLAC", "ASML", "NOW", "TEAM", "ZM", "DOCU", "CRWD", "OKTA", "DDOG", "NET", "FSLY", "ZS", "PLTR", "AI", "UBER", "LYFT", "SQ", "SHOP", "SPOT", "TWTR", "SNAP", "ROKU", "ETSY", "PINS", "BIDU", "TCEHY", "JD", "BABA", "NTES", "IQ", "MOMO", "SINA", "CNC", "GILD", "REGN", "BIIB", "VRTX", "ALXN", "AMGN", "BMRN", "INCY", "SRPT", "EXEL", "NBIX", "BLUE", "CRSP", "EDIT", "SGEN", "IONS", "PACB", "FGEN", "VRTX", "TWLO", "ZM", "DOCU", "DDOG", "NET", "FSLY", "ZS", "PLTR", "AI", "UBER", "LYFT", "SQ", "SHOP", "SPOT", "TWTR", "SNAP", "ROKU", "ETSY", "PINS", "BTC-USD", "ETH-USD", "XRP-USD", "LTC-USD", "BCH-USD", "ADA-USD", "DOT-USD", "LINK-USD", "XLM-USD", "DOGE-USD", "^GSPC", "^DJI", "^IXIC", "^RUT", "^VIX", "^FTSE", "^N225", "^HSI", "^SSEC", "^BSESN", "^AXJO"]

for ticker in tickers:
    print(f"Processing ticker: {ticker}")
    try:
        py12.main(ticker=ticker, start="2010-01-01", save_pdf_path=f"figuras/py12/{ticker}", d_list=[1, 2])
    # if it cant process, continue to the next ticker
    except Exception as e:
        print(f"Could not process ticker {ticker}. Error: {e}")
        continue
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded AAPL from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=2 ===
#
# === Analyzing objectives & local minima for d=2 ===
#
# [d=2] TRAIN minima:
#   s≈0.555584, J_train≈1.413640e+00, RMSE_train≈1.1890, RMSE_val≈1.4354, RMSE_test≈6.1387, RMSE_train_and_val≈1.2551, RMSE_Weighted_train≈1.0207, RMSE_Weighted_val≈1.8340, RMSE_Weighted_test≈7.0341, RMSE_Weighted_train_and_val≈1.2525
# ...
