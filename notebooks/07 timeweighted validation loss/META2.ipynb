# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="META", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[2])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded META from 2012-05-18 to 2025-11-28 (N=3403, log=True).
# Train length = 2041, val = 680, test = 682.
#
# === Building spectral solver for d=2 ===
#
# === Analyzing objectives & local minima for d=2 ===
#
# [d=2] TRAIN minima:
#   s≈0.001000, J_train≈1.632104e+03, RMSE_train≈40.3993, RMSE_val≈15.1561, RMSE_test≈59.5343, RMSE_train_and_val≈35.7999, RMSE_Weighted_train≈21.0395, RMSE_Weighted_val≈19.1447, RMSE_Weighted_test≈68.5697, RMSE_Weighted_train_and_val≈18.9233
#   s≈0.969968, J_train≈7.486731e-01, RMSE_train≈0.8653, RMSE_val≈1.6154, RMSE_test≈3.8707, RMSE_train_and_val≈1.1017, RMSE_Weighted_train≈0.6816, RMSE_Weighted_val≈2.0655, RMSE_Weighted_test≈4.2957, RMSE_Weighted_train_and_val≈1.2273
#   s≈0.999000, J_train≈3.100761e-02, RMSE_train≈0.1761, RMSE_val≈0.4164, RMSE_test≈1.6828, RMSE_train_and_val≈0.2580, RMSE_Weighted_train≈0.1401, RMSE_Weighted_val≈0.3823, RMSE_Weighted_test≈1.9675, RMSE_Weighted_train_and_val≈0.2918
# [d=2] VAL minima:
#   s≈0.452337, J_val≈2.227283e+00, RMSE_train≈57.0971, RMSE_val≈1.4924, RMSE_test≈13.2605, RMSE_train_and_val≈49.4562, RMSE_Weighted_train≈34.6407, RMSE_Weighted_val≈1.5509, RMSE_Weighted_test≈16.3485, RMSE_Weighted_train_and_val≈26.0043
#   s≈0.948989, J_val≈1.941660e-01, RMSE_train≈6.5049, RMSE_val≈0.4406, RMSE_test≈0.5634, RMSE_train_and_val≈5.6381, RMSE_Weighted_train≈3.9420, RMSE_Weighted_val≈0.4944, RMSE_Weighted_test≈0.7181, RMSE_Weighted_train_and_val≈2.9719
#   s≈0.998237, J_val≈1.337662e-01, RMSE_train≈0.2059, RMSE_val≈0.3657, RMSE_test≈1.1422, RMSE_train_and_val≈0.2554, RMSE_Weighted_train≈0.1786, RMSE_Weighted_val≈0.3755, RMSE_Weighted_test≈1.3529, RMSE_Weighted_train_and_val≈0.2773
# [d=2] BOTH minima:
#   s≈0.001000, J_both≈1.281634e+03, RMSE_train≈40.3993, RMSE_val≈15.1561, RMSE_test≈59.5343, RMSE_train_and_val≈35.7999, RMSE_Weighted_train≈21.0395, RMSE_Weighted_val≈19.1447, RMSE_Weighted_test≈68.5697, RMSE_Weighted_train_and_val≈18.9233
#   s≈0.968883, J_both≈1.151522e+00, RMSE_train≈0.9037, RMSE_val≈1.4686, RMSE_test≈3.4251, RMSE_train_and_val≈1.0731, RMSE_Weighted_train≈0.5803, RMSE_Weighted_val≈1.8828, RMSE_Weighted_test≈3.7968, RMSE_Weighted_train_and_val≈1.1043
#   s≈0.998222, J_both≈6.523156e-02, RMSE_train≈0.2059, RMSE_val≈0.3658, RMSE_test≈1.1299, RMSE_train_and_val≈0.2554, RMSE_Weighted_train≈0.1790, RMSE_Weighted_val≈0.3770, RMSE_Weighted_test≈1.3388, RMSE_Weighted_train_and_val≈0.2776
# [d=2] VAL-WEIGHTED minima:
#   s≈0.462084, J_val_w≈2.216728e+00, RMSE_train≈57.1246, RMSE_val≈1.5327, RMSE_test≈12.1262, RMSE_train_and_val≈49.4803, RMSE_Weighted_train≈34.7553, RMSE_Weighted_val≈1.4889, RMSE_Weighted_test≈15.0371, RMSE_Weighted_train_and_val≈26.0908
#   s≈0.943922, J_val_w≈2.232770e-01, RMSE_train≈8.2250, RMSE_val≈0.4601, RMSE_test≈0.6415, RMSE_train_and_val≈7.1272, RMSE_Weighted_train≈5.0168, RMSE_Weighted_val≈0.4725, RMSE_Weighted_test≈0.8365, RMSE_Weighted_train_and_val≈3.7756
#   s≈0.998563, J_val_w≈1.294124e-01, RMSE_train≈0.2010, RMSE_val≈0.3766, RMSE_test≈1.3952, RMSE_train_and_val≈0.2564, RMSE_Weighted_train≈0.1657, RMSE_Weighted_val≈0.3597, RMSE_Weighted_test≈1.6420, RMSE_Weighted_train_and_val≈0.2769
# [d=2] BOTH-WEIGHTED minima:
#   s≈0.001000, J_both_w≈3.580915e+02, RMSE_train≈40.3993, RMSE_val≈15.1561, RMSE_test≈59.5343, RMSE_train_and_val≈35.7999, RMSE_Weighted_train≈21.0395, RMSE_Weighted_val≈19.1447, RMSE_Weighted_test≈68.5697, RMSE_Weighted_train_and_val≈18.9233
#   s≈0.965420, J_both_w≈8.234728e-01, RMSE_train≈1.4577, RMSE_val≈1.0656, RMSE_test≈2.2309, RMSE_train_and_val≈1.3703, RMSE_Weighted_train≈0.7040, RMSE_Weighted_val≈1.3795, RMSE_Weighted_test≈2.4664, RMSE_Weighted_train_and_val≈0.9075
#   s≈0.998409, J_both_w≈7.602611e-02, RMSE_train≈0.2048, RMSE_val≈0.3689, RMSE_test≈1.2787, RMSE_train_and_val≈0.2558, RMSE_Weighted_train≈0.1727, RMSE_Weighted_val≈0.3632, RMSE_Weighted_test≈1.5092, RMSE_Weighted_train_and_val≈0.2757
# --- Plotting train/val/test for d=2, val minimum 1/3, s≈0.4523, MSE≈2.227283e+00 ---
# --- Plotting train/val/test for d=2, val minimum 2/3, s≈0.9490, MSE≈1.941660e-01 ---
# --- Plotting train/val/test for d=2, val minimum 3/3, s≈0.9982, MSE≈1.337662e-01 ---
# --- Plotting train/val/test for d=2, val_w minimum 1/3, s≈0.4621, MSE≈2.216728e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 2/3, s≈0.9439, MSE≈2.232770e-01 ---
# --- Plotting train/val/test for d=2, val_w minimum 3/3, s≈0.9986, MSE≈1.294124e-01 ---
# --- Plotting train/val/test for d=2, both minimum 1/3, s≈0.0010, MSE≈1.281634e+03 ---
# --- Plotting train/val/test for d=2, both minimum 2/3, s≈0.9689, MSE≈1.151522e+00 ---
# --- Plotting train/val/test for d=2, both minimum 3/3, s≈0.9982, MSE≈6.523156e-02 ---
# --- Plotting train/val/test for d=2, both_w minimum 1/3, s≈0.0010, MSE≈3.580915e+02 ---
# --- Plotting train/val/test for d=2, both_w minimum 2/3, s≈0.9654, MSE≈8.234728e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 3/3, s≈0.9984, MSE≈7.602611e-02 ---
# --- Plotting train/val/test for d=2, train minimum 1/3, s≈0.0010, MSE≈1.632104e+03 ---
# --- Plotting train/val/test for d=2, train minimum 2/3, s≈0.9700, MSE≈7.486731e-01 ---
# --- Plotting train/val/test for d=2, train minimum 3/3, s≈0.9990, MSE≈3.100761e-02 ---
