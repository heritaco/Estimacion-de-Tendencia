# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="NVDA", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[1])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded NVDA from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=1 ===
#
# === Analyzing objectives & local minima for d=1 ===
#
# [d=1] TRAIN minima:
#   s≈0.001000, J_train≈5.945328e-01, RMSE_train≈0.7711, RMSE_val≈0.8009, RMSE_test≈1.7418, RMSE_train_and_val≈0.7786, RMSE_Weighted_train≈0.7313, RMSE_Weighted_val≈0.9154, RMSE_Weighted_test≈1.9904, RMSE_Weighted_train_and_val≈0.7705
#   s≈0.999000, J_train≈3.120810e-01, RMSE_train≈0.5586, RMSE_val≈0.4432, RMSE_test≈1.0460, RMSE_train_and_val≈0.5321, RMSE_Weighted_train≈0.5599, RMSE_Weighted_val≈0.4983, RMSE_Weighted_test≈1.2165, RMSE_Weighted_train_and_val≈0.5153
# [d=1] VAL minima:
#   s≈0.001000, J_val≈6.413689e-01, RMSE_train≈0.7711, RMSE_val≈0.8009, RMSE_test≈1.7418, RMSE_train_and_val≈0.7786, RMSE_Weighted_train≈0.7313, RMSE_Weighted_val≈0.9154, RMSE_Weighted_test≈1.9904, RMSE_Weighted_train_and_val≈0.7705
#   s≈0.998682, J_val≈1.909550e-01, RMSE_train≈0.5855, RMSE_val≈0.4370, RMSE_test≈1.0544, RMSE_train_and_val≈0.5522, RMSE_Weighted_train≈0.5852, RMSE_Weighted_val≈0.4904, RMSE_Weighted_test≈1.2272, RMSE_Weighted_train_and_val≈0.5285
# [d=1] BOTH minima:
#   s≈0.001000, J_both≈6.062382e-01, RMSE_train≈0.7711, RMSE_val≈0.8009, RMSE_test≈1.7418, RMSE_train_and_val≈0.7786, RMSE_Weighted_train≈0.7313, RMSE_Weighted_val≈0.9154, RMSE_Weighted_test≈1.9904, RMSE_Weighted_train_and_val≈0.7705
#   s≈0.999000, J_both≈2.831809e-01, RMSE_train≈0.5586, RMSE_val≈0.4432, RMSE_test≈1.0460, RMSE_train_and_val≈0.5321, RMSE_Weighted_train≈0.5599, RMSE_Weighted_val≈0.4983, RMSE_Weighted_test≈1.2165, RMSE_Weighted_train_and_val≈0.5153
# [d=1] VAL-WEIGHTED minima:
#   s≈0.001000, J_val_w≈8.380089e-01, RMSE_train≈0.7711, RMSE_val≈0.8009, RMSE_test≈1.7418, RMSE_train_and_val≈0.7786, RMSE_Weighted_train≈0.7313, RMSE_Weighted_val≈0.9154, RMSE_Weighted_test≈1.9904, RMSE_Weighted_train_and_val≈0.7705
#   s≈0.998674, J_val_w≈2.404750e-01, RMSE_train≈0.5861, RMSE_val≈0.4370, RMSE_test≈1.0548, RMSE_train_and_val≈0.5526, RMSE_Weighted_train≈0.5857, RMSE_Weighted_val≈0.4904, RMSE_Weighted_test≈1.2277, RMSE_Weighted_train_and_val≈0.5288
# [d=1] BOTH-WEIGHTED minima:
#   s≈0.001000, J_both_w≈5.937094e-01, RMSE_train≈0.7711, RMSE_val≈0.8009, RMSE_test≈1.7418, RMSE_train_and_val≈0.7786, RMSE_Weighted_train≈0.7313, RMSE_Weighted_val≈0.9154, RMSE_Weighted_test≈1.9904, RMSE_Weighted_train_and_val≈0.7705
#   s≈0.999000, J_both_w≈2.655195e-01, RMSE_train≈0.5586, RMSE_val≈0.4432, RMSE_test≈1.0460, RMSE_train_and_val≈0.5321, RMSE_Weighted_train≈0.5599, RMSE_Weighted_val≈0.4983, RMSE_Weighted_test≈1.2165, RMSE_Weighted_train_and_val≈0.5153
# --- Plotting train/val/test for d=1, val minimum 1/2, s≈0.0010, MSE≈6.413689e-01 ---
# --- Plotting train/val/test for d=1, val minimum 2/2, s≈0.9987, MSE≈1.909550e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 1/2, s≈0.0010, MSE≈8.380089e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 2/2, s≈0.9987, MSE≈2.404750e-01 ---
# --- Plotting train/val/test for d=1, both minimum 1/2, s≈0.0010, MSE≈6.062382e-01 ---
# --- Plotting train/val/test for d=1, both minimum 2/2, s≈0.9990, MSE≈2.831809e-01 ---
# --- Plotting train/val/test for d=1, both_w minimum 1/2, s≈0.0010, MSE≈5.937094e-01 ---
# --- Plotting train/val/test for d=1, both_w minimum 2/2, s≈0.9990, MSE≈2.655195e-01 ---
# --- Plotting train/val/test for d=1, train minimum 1/2, s≈0.0010, MSE≈5.945328e-01 ---
# --- Plotting train/val/test for d=1, train minimum 2/2, s≈0.9990, MSE≈3.120810e-01 ---
