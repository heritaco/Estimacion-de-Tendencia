# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="META", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[1])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded META from 2012-05-18 to 2025-11-28 (N=3403, log=True).
# Train length = 2041, val = 680, test = 682.
#
# === Building spectral solver for d=1 ===
#
# === Analyzing objectives & local minima for d=1 ===
#
# [d=1] TRAIN minima:
#   s≈0.844935, J_train≈7.489801e-02, RMSE_train≈0.2737, RMSE_val≈0.5838, RMSE_test≈0.3257, RMSE_train_and_val≈0.3760, RMSE_Weighted_train≈0.2357, RMSE_Weighted_val≈0.7563, RMSE_Weighted_test≈0.2067, RMSE_Weighted_train_and_val≈0.4413
#   s≈0.999000, J_train≈7.428953e-02, RMSE_train≈0.2726, RMSE_val≈0.7068, RMSE_test≈0.5557, RMSE_train_and_val≈0.4250, RMSE_Weighted_train≈0.2530, RMSE_Weighted_val≈0.9153, RMSE_Weighted_test≈0.4621, RMSE_Weighted_train_and_val≈0.5250
# [d=1] VAL minima:
#   s≈0.001000, J_val≈2.912991e-01, RMSE_train≈0.2817, RMSE_val≈0.5397, RMSE_test≈0.2547, RMSE_train_and_val≈0.3638, RMSE_Weighted_train≈0.2153, RMSE_Weighted_val≈0.6943, RMSE_Weighted_test≈0.1458, RMSE_Weighted_train_and_val≈0.4067
#   s≈0.986257, J_val≈3.502394e-01, RMSE_train≈0.3317, RMSE_val≈0.5918, RMSE_test≈0.3586, RMSE_train_and_val≈0.4124, RMSE_Weighted_train≈0.3176, RMSE_Weighted_val≈0.7651, RMSE_Weighted_test≈0.2515, RMSE_Weighted_train_and_val≈0.4739
# [d=1] BOTH minima:
#   s≈0.038153, J_both≈1.323143e-01, RMSE_train≈0.2816, RMSE_val≈0.5399, RMSE_test≈0.2549, RMSE_train_and_val≈0.3638, RMSE_Weighted_train≈0.2158, RMSE_Weighted_val≈0.6945, RMSE_Weighted_test≈0.1459, RMSE_Weighted_train_and_val≈0.4069
#   s≈0.998864, J_both≈1.803456e-01, RMSE_train≈0.2798, RMSE_val≈0.6977, RMSE_test≈0.5431, RMSE_train_and_val≈0.4247, RMSE_Weighted_train≈0.2606, RMSE_Weighted_val≈0.9042, RMSE_Weighted_test≈0.4494, RMSE_Weighted_train_and_val≈0.5213
# [d=1] VAL-WEIGHTED minima:
#   s≈0.001000, J_val_w≈4.820549e-01, RMSE_train≈0.2817, RMSE_val≈0.5397, RMSE_test≈0.2547, RMSE_train_and_val≈0.3638, RMSE_Weighted_train≈0.2153, RMSE_Weighted_val≈0.6943, RMSE_Weighted_test≈0.1458, RMSE_Weighted_train_and_val≈0.4067
#   s≈0.986665, J_val_w≈5.852972e-01, RMSE_train≈0.3334, RMSE_val≈0.5918, RMSE_test≈0.3590, RMSE_train_and_val≈0.4134, RMSE_Weighted_train≈0.3195, RMSE_Weighted_val≈0.7650, RMSE_Weighted_test≈0.2522, RMSE_Weighted_train_and_val≈0.4746
# [d=1] BOTH-WEIGHTED minima:
#   s≈0.001000, J_both_w≈1.653841e-01, RMSE_train≈0.2817, RMSE_val≈0.5397, RMSE_test≈0.2547, RMSE_train_and_val≈0.3638, RMSE_Weighted_train≈0.2153, RMSE_Weighted_val≈0.6943, RMSE_Weighted_test≈0.1458, RMSE_Weighted_train_and_val≈0.4067
# --- Plotting train/val/test for d=1, val minimum 1/2, s≈0.0010, MSE≈2.912991e-01 ---
# --- Plotting train/val/test for d=1, val minimum 2/2, s≈0.9863, MSE≈3.502394e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 1/2, s≈0.0010, MSE≈4.820549e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 2/2, s≈0.9867, MSE≈5.852972e-01 ---
# --- Plotting train/val/test for d=1, both minimum 1/2, s≈0.0382, MSE≈1.323143e-01 ---
# --- Plotting train/val/test for d=1, both minimum 2/2, s≈0.9989, MSE≈1.803456e-01 ---
# --- Plotting train/val/test for d=1, both_w minimum 1/1, s≈0.0010, MSE≈1.653841e-01 ---
# --- Plotting train/val/test for d=1, train minimum 1/2, s≈0.8449, MSE≈7.489801e-02 ---
# --- Plotting train/val/test for d=1, train minimum 2/2, s≈0.9990, MSE≈7.428953e-02 ---
