# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="^MXX", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[1])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded ^MXX from 2010-01-04 to 2025-11-28 (N=3991, log=True).
# Train length = 2394, val = 798, test = 799.
#
# === Building spectral solver for d=1 ===
#
# === Analyzing objectives & local minima for d=1 ===
#
# [d=1] TRAIN minima:
#   s≈0.999000, J_train≈5.603926e-03, RMSE_train≈0.0749, RMSE_val≈0.1677, RMSE_test≈0.0844, RMSE_train_and_val≈0.1060, RMSE_Weighted_train≈0.0787, RMSE_Weighted_val≈0.1361, RMSE_Weighted_test≈0.0859, RMSE_Weighted_train_and_val≈0.1232
# [d=1] VAL minima:
#   s≈0.986061, J_val≈1.250971e-02, RMSE_train≈0.1392, RMSE_val≈0.1118, RMSE_test≈0.0933, RMSE_train_and_val≈0.1329, RMSE_Weighted_train≈0.1473, RMSE_Weighted_val≈0.1056, RMSE_Weighted_test≈0.0987, RMSE_Weighted_train_and_val≈0.1326
# [d=1] BOTH minima:
#   s≈0.998600, J_both≈1.105338e-02, RMSE_train≈0.0816, RMSE_val≈0.1557, RMSE_test≈0.0714, RMSE_train_and_val≈0.1051, RMSE_Weighted_train≈0.0855, RMSE_Weighted_val≈0.1253, RMSE_Weighted_test≈0.0733, RMSE_Weighted_train_and_val≈0.1191
# [d=1] VAL-WEIGHTED minima:
#   s≈0.995197, J_val_w≈9.990994e-03, RMSE_train≈0.1206, RMSE_val≈0.1169, RMSE_test≈0.0659, RMSE_train_and_val≈0.1197, RMSE_Weighted_train≈0.1267, RMSE_Weighted_val≈0.1000, RMSE_Weighted_test≈0.0707, RMSE_Weighted_train_and_val≈0.1216
# [d=1] BOTH-WEIGHTED minima:
#   s≈0.997643, J_both_w≈1.343005e-02, RMSE_train≈0.0970, RMSE_val≈0.1356, RMSE_test≈0.0553, RMSE_train_and_val≈0.1080, RMSE_Weighted_train≈0.1015, RMSE_Weighted_val≈0.1089, RMSE_Weighted_test≈0.0584, RMSE_Weighted_train_and_val≈0.1159
# --- Plotting train/val/test for d=1, val minimum 1/1, s≈0.9861, MSE≈1.250971e-02 ---
# --- Plotting train/val/test for d=1, val_w minimum 1/1, s≈0.9952, MSE≈9.990994e-03 ---
# --- Plotting train/val/test for d=1, both minimum 1/1, s≈0.9986, MSE≈1.105338e-02 ---
# --- Plotting train/val/test for d=1, both_w minimum 1/1, s≈0.9976, MSE≈1.343005e-02 ---
# --- Plotting train/val/test for d=1, train minimum 1/1, s≈0.9990, MSE≈5.603926e-03 ---
