# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="^MXX", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[2])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded ^MXX from 2010-01-04 to 2025-11-28 (N=3991, log=True).
# Train length = 2394, val = 798, test = 799.
#
# === Building spectral solver for d=2 ===
#
# === Analyzing objectives & local minima for d=2 ===
#
# [d=2] TRAIN minima:
#   s≈0.001000, J_train≈3.557983e+01, RMSE_train≈5.9649, RMSE_val≈3.3971, RMSE_test≈9.8838, RMSE_train_and_val≈5.4378, RMSE_Weighted_train≈4.5656, RMSE_Weighted_val≈4.1912, RMSE_Weighted_test≈11.0337, RMSE_Weighted_train_and_val≈4.1415
#   s≈0.713144, J_train≈4.662958e+00, RMSE_train≈2.1594, RMSE_val≈2.0601, RMSE_test≈6.3081, RMSE_train_and_val≈2.1350, RMSE_Weighted_train≈1.8492, RMSE_Weighted_val≈2.5522, RMSE_Weighted_test≈7.0872, RMSE_Weighted_train_and_val≈1.9805
#   s≈0.994992, J_train≈2.155740e-02, RMSE_train≈0.1468, RMSE_val≈0.3189, RMSE_test≈0.9015, RMSE_train_and_val≈0.2040, RMSE_Weighted_train≈0.1148, RMSE_Weighted_val≈0.3941, RMSE_Weighted_test≈1.0089, RMSE_Weighted_train_and_val≈0.2351
# [d=2] VAL minima:
#   s≈0.001000, J_val≈1.154005e+01, RMSE_train≈5.9649, RMSE_val≈3.3971, RMSE_test≈9.8838, RMSE_train_and_val≈5.4378, RMSE_Weighted_train≈4.5656, RMSE_Weighted_val≈4.1912, RMSE_Weighted_test≈11.0337, RMSE_Weighted_train_and_val≈4.1415
#   s≈0.717001, J_val≈4.241365e+00, RMSE_train≈2.1607, RMSE_val≈2.0595, RMSE_test≈6.3055, RMSE_train_and_val≈2.1358, RMSE_Weighted_train≈1.8498, RMSE_Weighted_val≈2.5514, RMSE_Weighted_test≈7.0842, RMSE_Weighted_train_and_val≈1.9805
#   s≈0.991849, J_val≈4.755590e-02, RMSE_train≈0.1808, RMSE_val≈0.2181, RMSE_test≈0.5441, RMSE_train_and_val≈0.1908, RMSE_Weighted_train≈0.1154, RMSE_Weighted_val≈0.2638, RMSE_Weighted_test≈0.6035, RMSE_Weighted_train_and_val≈0.1723
#   s≈0.994992, J_val≈1.017207e-01, RMSE_train≈0.1468, RMSE_val≈0.3189, RMSE_test≈0.9015, RMSE_train_and_val≈0.2040, RMSE_Weighted_train≈0.1148, RMSE_Weighted_val≈0.3941, RMSE_Weighted_test≈1.0089, RMSE_Weighted_train_and_val≈0.2351
# [d=2] BOTH minima:
#   s≈0.001000, J_both≈2.956988e+01, RMSE_train≈5.9649, RMSE_val≈3.3971, RMSE_test≈9.8838, RMSE_train_and_val≈5.4378, RMSE_Weighted_train≈4.5656, RMSE_Weighted_val≈4.1912, RMSE_Weighted_test≈11.0337, RMSE_Weighted_train_and_val≈4.1415
#   s≈0.713669, J_both≈4.558127e+00, RMSE_train≈2.1594, RMSE_val≈2.0599, RMSE_test≈6.3075, RMSE_train_and_val≈2.1350, RMSE_Weighted_train≈1.8492, RMSE_Weighted_val≈2.5520, RMSE_Weighted_test≈7.0866, RMSE_Weighted_train_and_val≈1.9804
#   s≈0.994992, J_both≈4.159822e-02, RMSE_train≈0.1468, RMSE_val≈0.3189, RMSE_test≈0.9015, RMSE_train_and_val≈0.2040, RMSE_Weighted_train≈0.1148, RMSE_Weighted_val≈0.3941, RMSE_Weighted_test≈1.0089, RMSE_Weighted_train_and_val≈0.2351
# [d=2] VAL-WEIGHTED minima:
#   s≈0.001000, J_val_w≈1.756591e+01, RMSE_train≈5.9649, RMSE_val≈3.3971, RMSE_test≈9.8838, RMSE_train_and_val≈5.4378, RMSE_Weighted_train≈4.5656, RMSE_Weighted_val≈4.1912, RMSE_Weighted_test≈11.0337, RMSE_Weighted_train_and_val≈4.1415
#   s≈0.717053, J_val_w≈6.509512e+00, RMSE_train≈2.1607, RMSE_val≈2.0595, RMSE_test≈6.3054, RMSE_train_and_val≈2.1359, RMSE_Weighted_train≈1.8498, RMSE_Weighted_val≈2.5514, RMSE_Weighted_test≈7.0842, RMSE_Weighted_train_and_val≈1.9805
#   s≈0.991848, J_val_w≈6.961457e-02, RMSE_train≈0.1808, RMSE_val≈0.2181, RMSE_test≈0.5441, RMSE_train_and_val≈0.1908, RMSE_Weighted_train≈0.1155, RMSE_Weighted_val≈0.2638, RMSE_Weighted_test≈0.6035, RMSE_Weighted_train_and_val≈0.1723
#   s≈0.994992, J_val_w≈1.553113e-01, RMSE_train≈0.1468, RMSE_val≈0.3189, RMSE_test≈0.9015, RMSE_train_and_val≈0.2040, RMSE_Weighted_train≈0.1148, RMSE_Weighted_val≈0.3941, RMSE_Weighted_test≈1.0089, RMSE_Weighted_train_and_val≈0.2351
# [d=2] BOTH-WEIGHTED minima:
#   s≈0.001000, J_both_w≈1.715165e+01, RMSE_train≈5.9649, RMSE_val≈3.3971, RMSE_test≈9.8838, RMSE_train_and_val≈5.4378, RMSE_Weighted_train≈4.5656, RMSE_Weighted_val≈4.1912, RMSE_Weighted_test≈11.0337, RMSE_Weighted_train_and_val≈4.1415
#   s≈0.715099, J_both_w≈3.921432e+00, RMSE_train≈2.1597, RMSE_val≈2.0596, RMSE_test≈6.3063, RMSE_train_and_val≈2.1351, RMSE_Weighted_train≈1.8493, RMSE_Weighted_val≈2.5516, RMSE_Weighted_test≈7.0852, RMSE_Weighted_train_and_val≈1.9803
#   s≈0.992134, J_both_w≈2.943357e-02, RMSE_train≈0.1741, RMSE_val≈0.2190, RMSE_test≈0.5485, RMSE_train_and_val≈0.1864, RMSE_Weighted_train≈0.1120, RMSE_Weighted_val≈0.2651, RMSE_Weighted_test≈0.6086, RMSE_Weighted_train_and_val≈0.1716
#   s≈0.994992, J_both_w≈5.526971e-02, RMSE_train≈0.1468, RMSE_val≈0.3189, RMSE_test≈0.9015, RMSE_train_and_val≈0.2040, RMSE_Weighted_train≈0.1148, RMSE_Weighted_val≈0.3941, RMSE_Weighted_test≈1.0089, RMSE_Weighted_train_and_val≈0.2351
# --- Plotting train/val/test for d=2, val minimum 1/4, s≈0.0010, MSE≈1.154005e+01 ---
# --- Plotting train/val/test for d=2, val minimum 2/4, s≈0.7170, MSE≈4.241365e+00 ---
# --- Plotting train/val/test for d=2, val minimum 3/4, s≈0.9918, MSE≈4.755590e-02 ---
# --- Plotting train/val/test for d=2, val minimum 4/4, s≈0.9950, MSE≈1.017207e-01 ---
# --- Plotting train/val/test for d=2, val_w minimum 1/4, s≈0.0010, MSE≈1.756591e+01 ---
# --- Plotting train/val/test for d=2, val_w minimum 2/4, s≈0.7171, MSE≈6.509512e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 3/4, s≈0.9918, MSE≈6.961457e-02 ---
# --- Plotting train/val/test for d=2, val_w minimum 4/4, s≈0.9950, MSE≈1.553113e-01 ---
# --- Plotting train/val/test for d=2, both minimum 1/3, s≈0.0010, MSE≈2.956988e+01 ---
# --- Plotting train/val/test for d=2, both minimum 2/3, s≈0.7137, MSE≈4.558127e+00 ---
# --- Plotting train/val/test for d=2, both minimum 3/3, s≈0.9950, MSE≈4.159822e-02 ---
# --- Plotting train/val/test for d=2, both_w minimum 1/4, s≈0.0010, MSE≈1.715165e+01 ---
# --- Plotting train/val/test for d=2, both_w minimum 2/4, s≈0.7151, MSE≈3.921432e+00 ---
# --- Plotting train/val/test for d=2, both_w minimum 3/4, s≈0.9921, MSE≈2.943357e-02 ---
# --- Plotting train/val/test for d=2, both_w minimum 4/4, s≈0.9950, MSE≈5.526971e-02 ---
# --- Plotting train/val/test for d=2, train minimum 1/3, s≈0.0010, MSE≈3.557983e+01 ---
# --- Plotting train/val/test for d=2, train minimum 2/3, s≈0.7131, MSE≈4.662958e+00 ---
# --- Plotting train/val/test for d=2, train minimum 3/3, s≈0.9950, MSE≈2.155740e-02 ---
