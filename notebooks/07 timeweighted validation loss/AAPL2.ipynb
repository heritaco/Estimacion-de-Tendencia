# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="AAPL", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[1])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# PDFs will be saved to: figuras/py12/AAPL/
# Loaded AAPL from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=1 ===
#
# === Analyzing objectives & local minima for d=1 ===
#
# [d=1] TRAIN minima:
#   s≈0.001000, J_train≈4.670611e-02, RMSE_train≈0.2161, RMSE_val≈0.4981, RMSE_test≈0.3524, RMSE_train_and_val≈0.3115, RMSE_Weighted_train≈0.1885, RMSE_Weighted_val≈0.5564, RMSE_Weighted_test≈0.3357, RMSE_Weighted_train_and_val≈0.3638
#   s≈0.999000, J_train≈2.515941e-02, RMSE_train≈0.1586, RMSE_val≈0.4999, RMSE_test≈0.3987, RMSE_train_and_val≈0.2852, RMSE_Weighted_train≈0.1453, RMSE_Weighted_val≈0.5629, RMSE_Weighted_test≈0.3897, RMSE_Weighted_train_and_val≈0.3541
# [d=1] VAL minima:
#   s≈0.001000, J_val≈2.480878e-01, RMSE_train≈0.2161, RMSE_val≈0.4981, RMSE_test≈0.3524, RMSE_train_and_val≈0.3115, RMSE_Weighted_train≈0.1885, RMSE_Weighted_val≈0.5564, RMSE_Weighted_test≈0.3357, RMSE_Weighted_train_and_val≈0.3638
#   s≈0.998342, J_val≈2.485436e-01, RMSE_train≈0.1656, RMSE_val≈0.4985, RMSE_test≈0.3874, RMSE_train_and_val≈0.2876, RMSE_Weighted_train≈0.1510, RMSE_Weighted_val≈0.5604, RMSE_Weighted_test≈0.3767, RMSE_Weighted_train_and_val≈0.3544
# [d=1] BOTH minima:
#   s≈0.001000, J_both≈9.703581e-02, RMSE_train≈0.2161, RMSE_val≈0.4981, RMSE_test≈0.3524, RMSE_train_and_val≈0.3115, RMSE_Weighted_train≈0.1885, RMSE_Weighted_val≈0.5564, RMSE_Weighted_test≈0.3357, RMSE_Weighted_train_and_val≈0.3638
#   s≈0.999000, J_both≈8.133694e-02, RMSE_train≈0.1586, RMSE_val≈0.4999, RMSE_test≈0.3987, RMSE_train_and_val≈0.2852, RMSE_Weighted_train≈0.1453, RMSE_Weighted_val≈0.5629, RMSE_Weighted_test≈0.3897, RMSE_Weighted_train_and_val≈0.3541
# [d=1] VAL-WEIGHTED minima:
#   s≈0.001000, J_val_w≈3.096229e-01, RMSE_train≈0.2161, RMSE_val≈0.4981, RMSE_test≈0.3524, RMSE_train_and_val≈0.3115, RMSE_Weighted_train≈0.1885, RMSE_Weighted_val≈0.5564, RMSE_Weighted_test≈0.3357, RMSE_Weighted_train_and_val≈0.3638
#   s≈0.998198, J_val_w≈3.139772e-01, RMSE_train≈0.1674, RMSE_val≈0.4986, RMSE_test≈0.3857, RMSE_train_and_val≈0.2884, RMSE_Weighted_train≈0.1524, RMSE_Weighted_val≈0.5603, RMSE_Weighted_test≈0.3747, RMSE_Weighted_train_and_val≈0.3548
# [d=1] BOTH-WEIGHTED minima:
#   s≈0.001000, J_both_w≈1.323341e-01, RMSE_train≈0.2161, RMSE_val≈0.4981, RMSE_test≈0.3524, RMSE_train_and_val≈0.3115, RMSE_Weighted_train≈0.1885, RMSE_Weighted_val≈0.5564, RMSE_Weighted_test≈0.3357, RMSE_Weighted_train_and_val≈0.3638
#   s≈0.998780, J_both_w≈1.253028e-01, RMSE_train≈0.1607, RMSE_val≈0.4992, RMSE_test≈0.3944, RMSE_train_and_val≈0.2857, RMSE_Weighted_train≈0.1470, RMSE_Weighted_val≈0.5618, RMSE_Weighted_test≈0.3848, RMSE_Weighted_train_and_val≈0.3540
# --- Plotting train/val/test for d=1, val minimum 1/2, s≈0.0010, MSE≈2.480878e-01 ---
# --- Plotting train/val/test for d=1, val minimum 2/2, s≈0.9983, MSE≈2.485436e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 1/2, s≈0.0010, MSE≈3.096229e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 2/2, s≈0.9982, MSE≈3.139772e-01 ---
# --- Plotting train/val/test for d=1, both minimum 1/2, s≈0.0010, MSE≈9.703581e-02 ---
# --- Plotting train/val/test for d=1, both minimum 2/2, s≈0.9990, MSE≈8.133694e-02 ---
# --- Plotting train/val/test for d=1, both_w minimum 1/2, s≈0.0010, MSE≈1.323341e-01 ---
# --- Plotting train/val/test for d=1, both_w minimum 2/2, s≈0.9988, MSE≈1.253028e-01 ---
# --- Plotting train/val/test for d=1, train minimum 1/2, s≈0.0010, MSE≈4.670611e-02 ---
# --- Plotting train/val/test for d=1, train minimum 2/2, s≈0.9990, MSE≈2.515941e-02 ---
