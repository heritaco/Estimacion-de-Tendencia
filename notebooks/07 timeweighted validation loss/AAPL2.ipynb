# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '07 timeweighted validation loss'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py12_timeweighted as py12
importlib.reload(py12)
py12.main(ticker="AAPL", start="2010-01-01", save_pdf_path="figuras/py12", d_list=[2])
# Out:
# c:\Users\175199\Estimacion-de-Tendencia\notebooks\07 timeweighted validation loss\py12_timeweighted.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# PDFs will be saved to: figuras/py12/AAPL/
# Loaded AAPL from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=2 ===
#
# === Analyzing objectives & local minima for d=2 ===
#
# [d=2] TRAIN minima:
#   s≈0.555590, J_train≈1.413679e+00, RMSE_train≈1.1890, RMSE_val≈1.4355, RMSE_test≈6.1388, RMSE_train_and_val≈1.2551, RMSE_Weighted_train≈1.0207, RMSE_Weighted_val≈1.8340, RMSE_Weighted_test≈7.0342, RMSE_Weighted_train_and_val≈1.2525
#   s≈0.881208, J_train≈1.231556e+00, RMSE_train≈1.1098, RMSE_val≈0.3181, RMSE_test≈2.2966, RMSE_train_and_val≈0.9742, RMSE_Weighted_train≈0.5387, RMSE_Weighted_val≈0.4147, RMSE_Weighted_test≈2.6909, RMSE_Weighted_train_and_val≈0.4604
#   s≈0.978657, J_train≈3.481022e-01, RMSE_train≈0.5900, RMSE_val≈0.2282, RMSE_test≈0.8079, RMSE_train_and_val≈0.5236, RMSE_Weighted_train≈0.5138, RMSE_Weighted_val≈0.2247, RMSE_Weighted_test≈0.9618, RMSE_Weighted_train_and_val≈0.4138
#   s≈0.997107, J_train≈5.388118e-02, RMSE_train≈0.2321, RMSE_val≈1.0106, RMSE_test≈1.9474, RMSE_train_and_val≈0.5438, RMSE_Weighted_train≈0.2156, RMSE_Weighted_val≈1.1863, RMSE_Weighted_test≈2.1382, RMSE_Weighted_train_and_val≈0.7050
# [d=2] VAL minima:
#   s≈0.916189, J_val≈6.485086e-02, RMSE_train≈1.4943, RMSE_val≈0.2547, RMSE_test≈2.0107, RMSE_train_and_val≈1.3004, RMSE_Weighted_train≈0.7494, RMSE_Weighted_val≈0.3126, RMSE_Weighted_test≈2.3767, RMSE_Weighted_train_and_val≈0.5886
#   s≈0.977562, J_val≈3.929129e-02, RMSE_train≈0.5995, RMSE_val≈0.1982, RMSE_test≈1.1906, RMSE_train_and_val≈0.5286, RMSE_Weighted_train≈0.5489, RMSE_Weighted_val≈0.2134, RMSE_Weighted_test≈1.3981, RMSE_Weighted_train_and_val≈0.4326
#   s≈0.989681, J_val≈1.013687e-01, RMSE_train≈1.4857, RMSE_val≈0.3184, RMSE_test≈0.1015, RMSE_train_and_val≈1.2965, RMSE_Weighted_train≈1.0092, RMSE_Weighted_val≈0.3380, RMSE_Weighted_test≈0.1168, RMSE_Weighted_train_and_val≈0.7863
#   s≈0.999000, J_val≈4.266303e-01, RMSE_train≈0.2880, RMSE_val≈0.6532, RMSE_test≈0.9030, RMSE_train_and_val≈0.4109, RMSE_Weighted_train≈0.2062, RMSE_Weighted_val≈0.7509, RMSE_Weighted_test≈0.9662, RMSE_Weighted_train_and_val≈0.4681
# [d=2] BOTH minima:
#   s≈0.570175, J_both≈1.540250e+00, RMSE_train≈1.2075, RMSE_val≈1.3368, RMSE_test≈5.8514, RMSE_train_and_val≈1.2411, RMSE_Weighted_train≈0.9282, RMSE_Weighted_val≈1.7119, RMSE_Weighted_test≈6.7138, RMSE_Weighted_train_and_val≈1.1566
#   s≈0.881747, J_both≈9.489326e-01, RMSE_train≈1.1098, RMSE_val≈0.3166, RMSE_test≈2.2898, RMSE_train_and_val≈0.9741, RMSE_Weighted_train≈0.5387, RMSE_Weighted_val≈0.4126, RMSE_Weighted_test≈2.6832, RMSE_Weighted_train_and_val≈0.4599
#   s≈0.978371, J_both≈2.733192e-01, RMSE_train≈0.5907, RMSE_val≈0.2154, RMSE_test≈0.9056, RMSE_train_and_val≈0.5228, RMSE_Weighted_train≈0.5219, RMSE_Weighted_val≈0.2132, RMSE_Weighted_test≈1.0734, RMSE_Weighted_train_and_val≈0.4165
#   s≈0.999000, J_both≈1.688199e-01, RMSE_train≈0.2880, RMSE_val≈0.6532, RMSE_test≈0.9030, RMSE_train_and_val≈0.4109, RMSE_Weighted_train≈0.2062, RMSE_Weighted_val≈0.7509, RMSE_Weighted_test≈0.9662, RMSE_Weighted_train_and_val≈0.4681
# [d=2] VAL-WEIGHTED minima:
#   s≈0.916852, J_val_w≈9.763503e-02, RMSE_train≈1.5079, RMSE_val≈0.2547, RMSE_test≈2.0128, RMSE_train_and_val≈1.3121, RMSE_Weighted_train≈0.7571, RMSE_Weighted_val≈0.3125, RMSE_Weighted_test≈2.3794, RMSE_Weighted_train_and_val≈0.5941
#   s≈0.977966, J_val_w≈4.275183e-02, RMSE_train≈0.5940, RMSE_val≈0.2027, RMSE_test≈1.0471, RMSE_train_and_val≈0.5243, RMSE_Weighted_train≈0.5347, RMSE_Weighted_val≈0.2068, RMSE_Weighted_test≈1.2348, RMSE_Weighted_train_and_val≈0.4230
#   s≈0.989698, J_val_w≈1.142233e-01, RMSE_train≈1.4854, RMSE_val≈0.3184, RMSE_test≈0.1016, RMSE_train_and_val≈1.2963, RMSE_Weighted_train≈1.0090, RMSE_Weighted_val≈0.3380, RMSE_Weighted_test≈0.1170, RMSE_Weighted_train_and_val≈0.7861
#   s≈0.999000, J_val_w≈5.638910e-01, RMSE_train≈0.2880, RMSE_val≈0.6532, RMSE_test≈0.9030, RMSE_train_and_val≈0.4109, RMSE_Weighted_train≈0.2062, RMSE_Weighted_val≈0.7509, RMSE_Weighted_test≈0.9662, RMSE_Weighted_train_and_val≈0.4681
# [d=2] BOTH-WEIGHTED minima:
#   s≈0.886319, J_both_w≈2.095523e-01, RMSE_train≈1.1164, RMSE_val≈0.3046, RMSE_test≈2.2347, RMSE_train_and_val≈0.9788, RMSE_Weighted_train≈0.5415, RMSE_Weighted_val≈0.3952, RMSE_Weighted_test≈2.6209, RMSE_Weighted_train_and_val≈0.4578
#   s≈0.942690, J_both_w≈4.573210e-01, RMSE_train≈1.5792, RMSE_val≈0.5111, RMSE_test≈3.1711, RMSE_train_and_val≈1.3914, RMSE_Weighted_train≈0.7670, RMSE_Weighted_val≈0.6742, RMSE_Weighted_test≈3.6958, RMSE_Weighted_train_and_val≈0.6763
#   s≈0.979001, J_both_w≈1.702940e-01, RMSE_train≈0.5911, RMSE_val≈0.2468, RMSE_test≈0.6929, RMSE_train_and_val≈0.5266, RMSE_Weighted_train≈0.5054, RMSE_Weighted_val≈0.2443, RMSE_Weighted_test≈0.8304, RMSE_Weighted_train_and_val≈0.4127
#   s≈0.999000, J_both_w≈2.190733e-01, RMSE_train≈0.2880, RMSE_val≈0.6532, RMSE_test≈0.9030, RMSE_train_and_val≈0.4109, RMSE_Weighted_train≈0.2062, RMSE_Weighted_val≈0.7509, RMSE_Weighted_test≈0.9662, RMSE_Weighted_train_and_val≈0.4681
# --- Plotting train/val/test for d=2, val minimum 1/4, s≈0.9162, MSE≈6.485086e-02 ---
# --- Plotting train/val/test for d=2, val minimum 2/4, s≈0.9776, MSE≈3.929129e-02 ---
# --- Plotting train/val/test for d=2, val minimum 3/4, s≈0.9897, MSE≈1.013687e-01 ---
# --- Plotting train/val/test for d=2, val minimum 4/4, s≈0.9990, MSE≈4.266303e-01 ---
# --- Plotting train/val/test for d=2, val_w minimum 1/4, s≈0.9169, MSE≈9.763503e-02 ---
# --- Plotting train/val/test for d=2, val_w minimum 2/4, s≈0.9780, MSE≈4.275183e-02 ---
# --- Plotting train/val/test for d=2, val_w minimum 3/4, s≈0.9897, MSE≈1.142233e-01 ---
# --- Plotting train/val/test for d=2, val_w minimum 4/4, s≈0.9990, MSE≈5.638910e-01 ---
# --- Plotting train/val/test for d=2, both minimum 1/4, s≈0.5702, MSE≈1.540250e+00 ---
# --- Plotting train/val/test for d=2, both minimum 2/4, s≈0.8817, MSE≈9.489326e-01 ---
# --- Plotting train/val/test for d=2, both minimum 3/4, s≈0.9784, MSE≈2.733192e-01 ---
# --- Plotting train/val/test for d=2, both minimum 4/4, s≈0.9990, MSE≈1.688199e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 1/4, s≈0.8863, MSE≈2.095523e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 2/4, s≈0.9427, MSE≈4.573210e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 3/4, s≈0.9790, MSE≈1.702940e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 4/4, s≈0.9990, MSE≈2.190733e-01 ---
# --- Plotting train/val/test for d=2, train minimum 1/4, s≈0.5556, MSE≈1.413679e+00 ---
# --- Plotting train/val/test for d=2, train minimum 2/4, s≈0.8812, MSE≈1.231556e+00 ---
# --- Plotting train/val/test for d=2, train minimum 3/4, s≈0.9787, MSE≈3.481022e-01 ---
# --- Plotting train/val/test for d=2, train minimum 4/4, s≈0.9971, MSE≈5.388118e-02 ---
