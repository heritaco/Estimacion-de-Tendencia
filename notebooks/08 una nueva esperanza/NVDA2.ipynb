# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '08 una nueva esperanza'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py_11_multiple_minima as py12
importlib.reload(py12)
py12.main(ticker="NVDA", start="2010-01-01",  d_list=[1])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\08 una nueva esperanza\py_11_multiple_minima.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded NVDA from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=1 ===
#
# === Analyzing objectives & local minima for d=1 ===
#
# [d=1] TRAIN minima:
#   s≈0.000010, J_train≈5.945287e-01, RMSE_train≈0.0000, RMSE_val≈2.5645, RMSE_test≈4.3037, RMSE_train_and_val≈1.2820, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈2.8437, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7235
#   s≈0.999900, J_train≈2.520282e-01, RMSE_train≈0.4868, RMSE_val≈2.5635, RMSE_test≈4.3037, RMSE_train_and_val≈1.3491, RMSE_Weighted_train≈0.4848, RMSE_Weighted_val≈2.8436, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7609
# [d=1] VAL minima:
#   s≈0.000010, J_val≈6.413652e-01, RMSE_train≈0.0000, RMSE_val≈2.5645, RMSE_test≈4.3037, RMSE_train_and_val≈1.2820, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈2.8437, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7235
#   s≈0.998682, J_val≈1.909550e-01, RMSE_train≈0.2886, RMSE_val≈2.5617, RMSE_test≈4.3037, RMSE_train_and_val≈1.3048, RMSE_Weighted_train≈0.3023, RMSE_Weighted_val≈2.8434, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7368
# [d=1] BOTH minima:
#   s≈0.000010, J_both≈6.062342e-01, RMSE_train≈0.0000, RMSE_val≈2.5645, RMSE_test≈4.3037, RMSE_train_and_val≈1.2820, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈2.8437, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7235
#   s≈0.999654, J_both≈2.570586e-01, RMSE_train≈0.4448, RMSE_val≈2.5630, RMSE_test≈4.3037, RMSE_train_and_val≈1.3380, RMSE_Weighted_train≈0.4464, RMSE_Weighted_val≈2.8435, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7549
# [d=1] VAL-WEIGHTED minima:
#   s≈0.000010, J_val_w≈8.380041e-01, RMSE_train≈0.0000, RMSE_val≈2.5645, RMSE_test≈4.3037, RMSE_train_and_val≈1.2820, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈2.8437, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7235
#   s≈0.998674, J_val_w≈2.404750e-01, RMSE_train≈0.2877, RMSE_val≈2.5617, RMSE_test≈4.3037, RMSE_train_and_val≈1.3047, RMSE_Weighted_train≈0.3015, RMSE_Weighted_val≈2.8434, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7367
# [d=1] BOTH-WEIGHTED minima:
#   s≈0.000010, J_both_w≈5.937062e-01, RMSE_train≈0.0000, RMSE_val≈2.5645, RMSE_test≈4.3037, RMSE_train_and_val≈1.2820, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈2.8437, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7235
#   s≈0.999413, J_both_w≈2.565973e-01, RMSE_train≈0.4001, RMSE_val≈2.5625, RMSE_test≈4.3037, RMSE_train_and_val≈1.3271, RMSE_Weighted_train≈0.4056, RMSE_Weighted_val≈2.8435, RMSE_Weighted_test≈4.7052, RMSE_Weighted_train_and_val≈1.7491
# --- Plotting train/val/test for d=1, val minimum 1/2, s≈0.0000, MSE≈6.413652e-01 ---
# --- Plotting train/val/test for d=1, val minimum 2/2, s≈0.9987, MSE≈1.909550e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 1/2, s≈0.0000, MSE≈8.380041e-01 ---
# --- Plotting train/val/test for d=1, val_w minimum 2/2, s≈0.9987, MSE≈2.404750e-01 ---
# --- Plotting train/val/test for d=1, both minimum 1/2, s≈0.0000, MSE≈6.062342e-01 ---
# --- Plotting train/val/test for d=1, both minimum 2/2, s≈0.9997, MSE≈2.570586e-01 ---
# --- Plotting train/val/test for d=1, both_w minimum 1/2, s≈0.0000, MSE≈5.937062e-01 ---
# --- Plotting train/val/test for d=1, both_w minimum 2/2, s≈0.9994, MSE≈2.565973e-01 ---
# --- Plotting train/val/test for d=1, train minimum 1/2, s≈0.0000, MSE≈5.945287e-01 ---
# --- Plotting train/val/test for d=1, train minimum 2/2, s≈0.9999, MSE≈2.520282e-01 ---
