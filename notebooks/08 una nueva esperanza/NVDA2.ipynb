# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '08 una nueva esperanza'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py_11_multiple_minima as py12
importlib.reload(py12)
py12.main(ticker="NVDA", start="2010-01-01",  d_list=[2])
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\08 una nueva esperanza\py_11_multiple_minima.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded NVDA from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=2 ===
#
# === Analyzing objectives & local minima for d=2 ===
#
# [d=2] TRAIN minima:
#   s≈0.000010, J_train≈6.770877e+01, RMSE_train≈0.0000, RMSE_val≈1.0682, RMSE_test≈4.5626, RMSE_train_and_val≈0.5340, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈1.3128, RMSE_Weighted_test≈5.3057, RMSE_Weighted_train_and_val≈0.7317
#   s≈0.883540, J_train≈3.069085e+00, RMSE_train≈0.0227, RMSE_val≈0.4865, RMSE_test≈4.7583, RMSE_train_and_val≈0.2440, RMSE_Weighted_train≈0.0229, RMSE_Weighted_val≈0.5896, RMSE_Weighted_test≈5.6865, RMSE_Weighted_train_and_val≈0.3328
#   s≈0.971872, J_train≈7.988901e-01, RMSE_train≈0.0438, RMSE_val≈0.9493, RMSE_test≈4.5940, RMSE_train_and_val≈0.4761, RMSE_Weighted_train≈0.0441, RMSE_Weighted_val≈1.1752, RMSE_Weighted_test≈5.3723, RMSE_Weighted_train_and_val≈0.6520
#   s≈0.999900, J_train≈1.111257e-01, RMSE_train≈0.3282, RMSE_val≈0.7346, RMSE_test≈4.7256, RMSE_train_and_val≈0.4644, RMSE_Weighted_train≈0.3984, RMSE_Weighted_val≈0.7471, RMSE_Weighted_test≈5.6078, RMSE_Weighted_train_and_val≈0.5713
# [d=2] VAL minima:
#   s≈0.118646, J_val≈3.800514e-02, RMSE_train≈0.0022, RMSE_val≈0.8791, RMSE_test≈4.6132, RMSE_train_and_val≈0.4395, RMSE_Weighted_train≈0.0023, RMSE_Weighted_val≈1.0948, RMSE_Weighted_test≈5.4101, RMSE_Weighted_train_and_val≈0.6038
#   s≈0.630713, J_val≈2.207671e+00, RMSE_train≈0.0118, RMSE_val≈0.5946, RMSE_test≈4.7063, RMSE_train_and_val≈0.2974, RMSE_Weighted_train≈0.0119, RMSE_Weighted_val≈0.7469, RMSE_Weighted_test≈5.5907, RMSE_Weighted_train_and_val≈0.4092
#   s≈0.925665, J_val≈4.733283e+00, RMSE_train≈0.0285, RMSE_val≈0.6522, RMSE_test≈4.6845, RMSE_train_and_val≈0.3270, RMSE_Weighted_train≈0.0290, RMSE_Weighted_val≈0.8215, RMSE_Weighted_test≈5.5497, RMSE_Weighted_train_and_val≈0.4495
#   s≈0.975503, J_val≈1.221232e-01, RMSE_train≈0.0471, RMSE_val≈1.2138, RMSE_test≈4.5277, RMSE_train_and_val≈0.6082, RMSE_Weighted_train≈0.0475, RMSE_Weighted_val≈1.4752, RMSE_Weighted_test≈5.2323, RMSE_Weighted_train_and_val≈0.8304
#   s≈0.990943, J_val≈1.279551e+00, RMSE_train≈0.0825, RMSE_val≈1.6186, RMSE_test≈4.4415, RMSE_train_and_val≈0.8123, RMSE_Weighted_train≈0.0831, RMSE_Weighted_val≈1.9277, RMSE_Weighted_test≈5.0309, RMSE_Weighted_train_and_val≈1.1037
#   s≈0.998943, J_val≈9.209647e-02, RMSE_train≈0.2342, RMSE_val≈1.0524, RMSE_test≈4.5676, RMSE_train_and_val≈0.5639, RMSE_Weighted_train≈0.2676, RMSE_Weighted_val≈1.2936, RMSE_Weighted_test≈5.3031, RMSE_Weighted_train_and_val≈0.7483
# [d=2] BOTH minima:
#   s≈0.000010, J_both≈5.088375e+01, RMSE_train≈0.0000, RMSE_val≈1.0682, RMSE_test≈4.5626, RMSE_train_and_val≈0.5340, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈1.3128, RMSE_Weighted_test≈5.3057, RMSE_Weighted_train_and_val≈0.7317
#   s≈0.887358, J_both≈4.216474e+00, RMSE_train≈0.0231, RMSE_val≈0.5017, RMSE_test≈4.7492, RMSE_train_and_val≈0.2516, RMSE_Weighted_train≈0.0233, RMSE_Weighted_val≈0.6145, RMSE_Weighted_test≈5.6700, RMSE_Weighted_train_and_val≈0.3439
#   s≈0.972872, J_both≈7.576734e-01, RMSE_train≈0.0446, RMSE_val≈1.0168, RMSE_test≈4.5762, RMSE_train_and_val≈0.5098, RMSE_Weighted_train≈0.0450, RMSE_Weighted_val≈1.2525, RMSE_Weighted_test≈5.3356, RMSE_Weighted_train_and_val≈0.6977
#   s≈0.999484, J_both≈5.134058e-01, RMSE_train≈0.3006, RMSE_val≈0.7681, RMSE_test≈4.6802, RMSE_train_and_val≈0.4639, RMSE_Weighted_train≈0.3607, RMSE_Weighted_val≈0.8687, RMSE_Weighted_test≈5.5240, RMSE_Weighted_train_and_val≈0.5844
# [d=2] VAL-WEIGHTED minima:
#   s≈0.115566, J_val_w≈5.389813e-02, RMSE_train≈0.0022, RMSE_val≈0.8840, RMSE_test≈4.6118, RMSE_train_and_val≈0.4419, RMSE_Weighted_train≈0.0022, RMSE_Weighted_val≈1.1005, RMSE_Weighted_test≈5.4074, RMSE_Weighted_train_and_val≈0.6071
#   s≈0.628325, J_val_w≈3.547531e+00, RMSE_train≈0.0118, RMSE_val≈0.5933, RMSE_test≈4.7068, RMSE_train_and_val≈0.2968, RMSE_Weighted_train≈0.0119, RMSE_Weighted_val≈0.7451, RMSE_Weighted_test≈5.5917, RMSE_Weighted_train_and_val≈0.4083
#   s≈0.925689, J_val_w≈7.787544e+00, RMSE_train≈0.0285, RMSE_val≈0.6522, RMSE_test≈4.6845, RMSE_train_and_val≈0.3270, RMSE_Weighted_train≈0.0290, RMSE_Weighted_val≈0.8215, RMSE_Weighted_test≈5.5497, RMSE_Weighted_train_and_val≈0.4495
#   s≈0.975816, J_val_w≈1.671907e-01, RMSE_train≈0.0475, RMSE_val≈1.2384, RMSE_test≈4.5220, RMSE_train_and_val≈0.6205, RMSE_Weighted_train≈0.0478, RMSE_Weighted_val≈1.5028, RMSE_Weighted_test≈5.2197, RMSE_Weighted_train_and_val≈0.8469
#   s≈0.990968, J_val_w≈1.667257e+00, RMSE_train≈0.0826, RMSE_val≈1.6188, RMSE_test≈4.4415, RMSE_train_and_val≈0.8124, RMSE_Weighted_train≈0.0832, RMSE_Weighted_val≈1.9279, RMSE_Weighted_test≈5.0308, RMSE_Weighted_train_and_val≈1.1039
#   s≈0.998944, J_val_w≈9.113182e-02, RMSE_train≈0.2342, RMSE_val≈1.0522, RMSE_test≈4.5676, RMSE_train_and_val≈0.5638, RMSE_Weighted_train≈0.2676, RMSE_Weighted_val≈1.2934, RMSE_Weighted_test≈5.3032, RMSE_Weighted_train_and_val≈0.7483
# [d=2] BOTH-WEIGHTED minima:
#   s≈0.000010, J_both_w≈1.337296e+01, RMSE_train≈0.0000, RMSE_val≈1.0682, RMSE_test≈4.5626, RMSE_train_and_val≈0.5340, RMSE_Weighted_train≈0.0000, RMSE_Weighted_val≈1.3128, RMSE_Weighted_test≈5.3057, RMSE_Weighted_train_and_val≈0.7317
#   s≈0.722538, J_both_w≈7.988811e+00, RMSE_train≈0.0142, RMSE_val≈0.5584, RMSE_test≈4.7215, RMSE_train_and_val≈0.2794, RMSE_Weighted_train≈0.0142, RMSE_Weighted_val≈0.6977, RMSE_Weighted_test≈5.6190, RMSE_Weighted_train_and_val≈0.3839
#   s≈0.928555, J_both_w≈3.703304e+00, RMSE_train≈0.0291, RMSE_val≈0.6499, RMSE_test≈4.6853, RMSE_train_and_val≈0.3259, RMSE_Weighted_train≈0.0296, RMSE_Weighted_val≈0.8185, RMSE_Weighted_test≈5.5513, RMSE_Weighted_train_and_val≈0.4480
#   s≈0.974639, J_both_w≈4.611310e-01, RMSE_train≈0.0463, RMSE_val≈1.1467, RMSE_test≈4.5437, RMSE_train_and_val≈0.5746, RMSE_Weighted_train≈0.0466, RMSE_Weighted_val≈1.3996, RMSE_Weighted_test≈5.2669, RMSE_Weighted_train_and_val≈0.7852
#   s≈0.988966, J_both_w≈4.079441e+00, RMSE_train≈0.0737, RMSE_val≈1.6465, RMSE_test≈4.4361, RMSE_train_and_val≈0.8256, RMSE_Weighted_train≈0.0757, RMSE_Weighted_val≈1.9590, RMSE_Weighted_test≈5.0173, RMSE_Weighted_train_and_val≈1.1222
#   s≈0.999184, J_both_w≈4.972348e-01, RMSE_train≈0.2647, RMSE_val≈0.8893, RMSE_test≈4.6199, RMSE_train_and_val≈0.5002, RMSE_Weighted_train≈0.3109, RMSE_Weighted_val≈1.0780, RMSE_Weighted_test≈5.4082, RMSE_Weighted_train_and_val≈0.6508
# --- Plotting train/val/test for d=2, val minimum 1/6, s≈0.1186, MSE≈3.800514e-02 ---
# --- Plotting train/val/test for d=2, val minimum 2/6, s≈0.6307, MSE≈2.207671e+00 ---
# --- Plotting train/val/test for d=2, val minimum 3/6, s≈0.9257, MSE≈4.733283e+00 ---
# --- Plotting train/val/test for d=2, val minimum 4/6, s≈0.9755, MSE≈1.221232e-01 ---
# --- Plotting train/val/test for d=2, val minimum 5/6, s≈0.9909, MSE≈1.279551e+00 ---
# --- Plotting train/val/test for d=2, val minimum 6/6, s≈0.9989, MSE≈9.209647e-02 ---
# --- Plotting train/val/test for d=2, val_w minimum 1/6, s≈0.1156, MSE≈5.389813e-02 ---
# --- Plotting train/val/test for d=2, val_w minimum 2/6, s≈0.6283, MSE≈3.547531e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 3/6, s≈0.9257, MSE≈7.787544e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 4/6, s≈0.9758, MSE≈1.671907e-01 ---
# --- Plotting train/val/test for d=2, val_w minimum 5/6, s≈0.9910, MSE≈1.667257e+00 ---
# --- Plotting train/val/test for d=2, val_w minimum 6/6, s≈0.9989, MSE≈9.113182e-02 ---
# --- Plotting train/val/test for d=2, both minimum 1/4, s≈0.0000, MSE≈5.088375e+01 ---
# --- Plotting train/val/test for d=2, both minimum 2/4, s≈0.8874, MSE≈4.216474e+00 ---
# --- Plotting train/val/test for d=2, both minimum 3/4, s≈0.9729, MSE≈7.576734e-01 ---
# --- Plotting train/val/test for d=2, both minimum 4/4, s≈0.9995, MSE≈5.134058e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 1/6, s≈0.0000, MSE≈1.337296e+01 ---
# --- Plotting train/val/test for d=2, both_w minimum 2/6, s≈0.7225, MSE≈7.988811e+00 ---
# --- Plotting train/val/test for d=2, both_w minimum 3/6, s≈0.9286, MSE≈3.703304e+00 ---
# --- Plotting train/val/test for d=2, both_w minimum 4/6, s≈0.9746, MSE≈4.611310e-01 ---
# --- Plotting train/val/test for d=2, both_w minimum 5/6, s≈0.9890, MSE≈4.079441e+00 ---
# --- Plotting train/val/test for d=2, both_w minimum 6/6, s≈0.9992, MSE≈4.972348e-01 ---
# --- Plotting train/val/test for d=2, train minimum 1/4, s≈0.0000, MSE≈6.770877e+01 ---
# --- Plotting train/val/test for d=2, train minimum 2/4, s≈0.8835, MSE≈3.069085e+00 ---
# --- Plotting train/val/test for d=2, train minimum 3/4, s≈0.9719, MSE≈7.988901e-01 ---
# --- Plotting train/val/test for d=2, train minimum 4/4, s≈0.9999, MSE≈1.111257e-01 ---
