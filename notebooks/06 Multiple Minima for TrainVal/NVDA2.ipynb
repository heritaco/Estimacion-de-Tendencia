# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '06 Multiple Minima for TrainVal'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py_11_multiple_minima as py11
importlib.reload(py11)
py11.main(ticker="NVDA", start="2010-01-01", save_pdf_path="figuras/py11")
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\06 Multiple Minima for TrainVal\py_11_multiple_minima.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded NVDA from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=2 ===
#
# === Analyzing objectives & local minima for d=2 ===
#
# [d=2] TRAIN minima:
#   s≈0.001000, J_train≈6.783890e+01
#   s≈0.883540, J_train≈3.069082e+00
#   s≈0.971872, J_train≈7.988907e-01
#   s≈0.999000, J_train≈1.545368e+00
# [d=2] VAL minima:
#   s≈0.118642, J_val≈3.800457e-02
#   s≈0.630713, J_val≈2.207693e+00
#   s≈0.925666, J_val≈4.733284e+00
#   s≈0.975504, J_val≈1.221232e-01
#   s≈0.990943, J_val≈1.279552e+00
#   s≈0.998943, J_val≈9.209662e-02
# [d=2] BOTH minima:
#   s≈0.001000, J_both≈5.097995e+01
#   s≈0.887358, J_both≈4.216468e+00
#   s≈0.972872, J_both≈7.576739e-01
#   s≈0.999000, J_both≈1.185902e+00
# --- Plotting train/val/test for d=2, val minimum 1/6, s≈0.1186, MSE≈3.800457e-02 ---
# --- Plotting train/val/test for d=2, val minimum 2/6, s≈0.6307, MSE≈2.207693e+00 ---
# --- Plotting train/val/test for d=2, val minimum 3/6, s≈0.9257, MSE≈4.733284e+00 ---
# --- Plotting train/val/test for d=2, val minimum 4/6, s≈0.9755, MSE≈1.221232e-01 ---
# --- Plotting train/val/test for d=2, val minimum 5/6, s≈0.9909, MSE≈1.279552e+00 ---
# --- Plotting train/val/test for d=2, val minimum 6/6, s≈0.9989, MSE≈9.209662e-02 ---
# --- Plotting train/val/test for d=2, train minimum 1/4, s≈0.0010, MSE≈6.783890e+01 ---
# --- Plotting train/val/test for d=2, train minimum 2/4, s≈0.8835, MSE≈3.069082e+00 ---
# --- Plotting train/val/test for d=2, train minimum 3/4, s≈0.9719, MSE≈7.988907e-01 ---
# --- Plotting train/val/test for d=2, train minimum 4/4, s≈0.9990, MSE≈1.545368e+00 ---
# --- Plotting train/val/test for d=2, both minimum 1/4, s≈0.0010, MSE≈5.097995e+01 ---
# --- Plotting train/val/test for d=2, both minimum 2/4, s≈0.8874, MSE≈4.216468e+00 ---
# --- Plotting train/val/test for d=2, both minimum 3/4, s≈0.9729, MSE≈7.576739e-01 ---
# --- Plotting train/val/test for d=2, both minimum 4/4, s≈0.9990, MSE≈1.185902e+00 ---
