# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '103 different weighted'))

from scripts import style
importlib.reload(style)
style.set_style()

# %%
# STEP 0. Set up: import and reload py103, pull key functions

import importlib
import py103

# Always reload so edits to py103.py are picked up
importlib.reload(py103)

from py103 import (
    # Core data / transforms
    download_price_series,
    make_transformed_time_regression_data,
    TRANSFORM_FUNCS,

    # Core experiments
    run_transform_experiment,
    run_all_transforms_experiment,
    run_logprice_experiment,

    # Weighted training comparison
    run_weighted_training_comparison_single_transform,
    plot_weighted_training_comparison,

    # Normality-regularized selection
    run_normality_regularized_model_single_transform,

    # Residual diagnostics
    compute_validation_residuals_transform_and_price,
    compute_normality_stats,
    plot_validation_residual_diagnostics,

    # Plotting helpers
    plot_transform_trend,
    plot_destransformed_price_trend,
    subplot_all_transforms_and_destransforms,
)

# %%
# STEP 1. Basic: download NVDA and build (X, y, dates) for one transform

# 1A) Download NVDA close prices
df_nvda = download_price_series(
    ticker="NVDA",
    start="2015-01-01",
    end=None,          # up to latest available
)
print(df_nvda.head())
print(df_nvda.tail())
print(df_nvda.columns)

# 1B) Choose one transform (e.g. 'log_close') and build regression data
X_log, y_log, dates_log = make_transformed_time_regression_data(
    df=df_nvda,
    transform_name="log_close",   # any key in TRANSFORM_FUNCS
    price_col="close",
)

print("X_log shape:", X_log.shape)      # (n, 1)
print("y_log shape:", y_log.shape)      # (n,)
print("dates_log length:", len(dates_log))

# 1C) Inspect available transforms
print("Available transforms:", list(TRANSFORM_FUNCS.keys()))
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\103 different weighted\py103.py:31: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, progress=False)
# Price          close
# Ticker          NVDA
# Date
# 2015-01-02  0.483038
# 2015-01-05  0.474880
# 2015-01-06  0.460482
# 2015-01-07  0.459282
# 2015-01-08  0.476559
# Price            close
# Ticker            NVDA
# Date
# 2025-11-21  178.880005
# 2025-11-24  182.550003
# 2025-11-25  177.820007
# 2025-11-26  180.259995
# 2025-11-28  177.000000
# MultiIndex([('close', 'NVDA')],
#            names=['Price', 'Ticker'])
# X_log shape: (2744, 1)
# y_log shape: (2744,)
# dates_log length: 2744
# Available transforms: ['close', 'log_close', 'sqrt_close', 'diff_close', 'simple_return', 'log_return', 'zscore_log_close']

# %%
# STEP 2. Single-transform Elastic Net experiment + plots (transform & price space)

# 2A) Run full pipeline for ONE transform (e.g. 'log_close')
log_result, log_model, df_nvda = run_transform_experiment(
    transform_name="log_close",
    ticker="NVDA",
    start="2015-01-01",
    end=None,
    alpha=0.1,
    l1_ratio=0.5,
    random_state=0,
    train_frac=0.6,
    val_frac=0.2,
    poly_degree=1,         # 1 = linear in time; can try 2,3,...
)

# log_result["variance"] = variance of transformed series
print("\n[log_close] variance:", log_result["variance"])

# log_result["metrics"] is a dict with keys: 'train', 'val', 'test', 'train_val'
# Each entry has: rmse, rmse_w_linear, rmse_w_exp (all in TRANSFORM space)
print("\n=== Transform-space RMSE metrics (y_t) for log_close ===")
for split_name, m in log_result["metrics"].items():
    print(
        f"{split_name:9s} | "
        f"RMSE={m['rmse']:.6f}, "
        f"lin={m['rmse_w_linear']:.6f}, "
        f"exp={m['rmse_w_exp']:.6f}"
    )

# 2B) Plot in TRANSFORM space with colored train/val/test
plot_transform_trend(
    df=df_nvda,
    model=log_model,
    transform_name="log_close",
    train_frac=0.6,
    val_frac=0.2,
)

# 2C) Plot in PRICE space (detransformed trend vs Close)
plot_destransformed_price_trend(
    df=df_nvda,
    model=log_model,
    transform_name="log_close",
    train_frac=0.6,
    val_frac=0.2,
)
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\103 different weighted\py103.py:31: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, progress=False)
# === NVDA Elastic Net trend on transform 'log_close' (degree=1) ===
# Alpha=0.1000, l1_ratio=0.50
# Variance of transformed series: 2.742335e+00
#
# --- Metrics in TRANSFORM space (y_t) and PRICE space (Close) ---
# [train    ]  y: RMSE=0.380285, lin=0.337416, exp=0.324839   |  price: RMSE=1.603957, lin=1.851242, exp=1.850686
# [val      ]  y: RMSE=0.395646, lin=0.397221, exp=0.375377   |  price: RMSE=8.759559, lin=9.001509, exp=8.638061
# [test     ]  y: RMSE=0.466980, lin=0.490752, exp=0.480235   |  price: RMSE=49.782921, lin=56.981616, exp=57.410486
# [train_val]  y: RMSE=0.384179, lin=0.364121, exp=0.367513   |  price: RMSE=4.592938, lin=5.977809, exp=6.273328
#
# [log_close] variance: 2.742334647248084
#
# === Transform-space RMSE metrics (y_t) for log_close ===
# train     | RMSE=0.380285, lin=0.337416, exp=0.324839
# val       | RMSE=0.395646, lin=0.397221, exp=0.375377
# test      | RMSE=0.466980, lin=0.490752, exp=0.480235
# train_val | RMSE=0.384179, lin=0.364121, exp=0.367513

# %%
# STEP 3. Multi-transform experiment: compare all transforms numerically

# 3A) Run the experiment over ALL transforms in TRANSFORM_FUNCS
all_results, all_models, df_all = run_all_transforms_experiment(
    transform_names=None,      # None => use all transforms in TRANSFORM_FUNCS
    ticker="NVDA",
    start="2015-01-01",
    end=None,
    alpha=0.1,
    l1_ratio=0.5,
    random_state=0,
    train_frac=0.6,
    val_frac=0.2,
    poly_degree=1,
)

# all_results[transform_name] has:
#   - 'variance'
#   - 'metrics' (rmse, rmse_w_linear, rmse_w_exp for train/val/test/train_val)
print("\n=== SUMMARY: test RMSE in TRANSFORM space for each transform ===")
for name, res in all_results.items():
    m_test = res["metrics"]["test"]
    print(
        f"{name:16s} | "
        f"RMSE={m_test['rmse']:.6f}, "
        f"lin={m_test['rmse_w_linear']:.6f}, "
        f"exp={m_test['rmse_w_exp']:.6f}"
    )

# 3B) Global visualization: each transform in a row, with transform & price panels
subplot_all_transforms_and_destransforms(
    df=df_all,
    models=all_models,
    transform_names=None,   # None => all transforms
    train_frac=0.6,
    val_frac=0.2,
)
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\103 different weighted\py103.py:31: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, progress=False)
# === NVDA transform 'close' (degree=1) ===
# Variance: 2.324785e+03
# --- TRAIN / VAL / TEST metrics (transform vs price) ---
# [train    ]  y: RMSE=2.168647, lin=2.748693, exp=2.884650   |  price: RMSE=2.168647, lin=2.748693, exp=2.884650
# [val      ]  y: RMSE=14.184988, lin=16.706242, exp=17.899510   |  price: RMSE=14.184988, lin=16.706242, exp=17.899510
# [test     ]  y: RMSE=108.591444, lin=126.958001, exp=129.033450   |  price: RMSE=108.591444, lin=126.958001, exp=129.033450
#
# === NVDA transform 'log_close' (degree=1) ===
# Variance: 2.742335e+00
# --- TRAIN / VAL / TEST metrics (transform vs price) ---
# [train    ]  y: RMSE=0.380285, lin=0.337416, exp=0.324839   |  price: RMSE=1.603957, lin=1.851242, exp=1.850686
# [val      ]  y: RMSE=0.395646, lin=0.397221, exp=0.375377   |  price: RMSE=8.759559, lin=9.001509, exp=8.638061
# [test     ]  y: RMSE=0.466980, lin=0.490752, exp=0.480235   |  price: RMSE=49.782922, lin=56.981616, exp=57.410487
#
# === NVDA transform 'sqrt_close' (degree=1) ===
# Variance: 1.277834e+01
# --- TRAIN / VAL / TEST metrics (transform vs price) ---
# [train    ]  y: RMSE=0.357259, lin=0.422682, exp=0.430728   |  price: RMSE=1.979138, lin=2.530768, exp=2.667170
# [val      ]  y: RMSE=1.268103, lin=1.391148, exp=1.486884   |  price: RMSE=12.588901, lin=14.635936, exp=15.715711
# [test     ]  y: RMSE=6.096726, lin=6.895719, exp=6.943974   |  price: RMSE=102.746576, lin=120.315852, exp=122.318826
#
# === NVDA transform 'diff_close' (degree=1) ===
# Variance: 2.914640e+00
# --- TRAIN / VAL / TEST metrics (transform vs price) ---
# [train    ]  y: RMSE=0.188369, lin=0.241613, exp=0.253481   |  price: RMSE=4.819409, lin=5.479356, exp=5.333567
# [val      ]  y: RMSE=0.879167, lin=0.938946, exp=0.961691   |  price: RMSE=9.500766, lin=11.702972, exp=12.492082
# [test     ]  y: RMSE=3.697864, lin=4.043686, exp=3.983113   |  price: RMSE=100.011697, lin=117.782741, exp=119.888978
#
# === NVDA transform 'simple_return' (degree=1) ===
# Variance: 9.453631e-04
# --- TRAIN / VAL / TEST metrics (transform vs price) ---
# [train    ]  y: RMSE=0.028575, lin=0.029991, exp=0.029737   |  price: RMSE=5.563206, lin=7.385973, exp=7.882621
# [val      ]  y: RMSE=0.035973, lin=0.036003, exp=0.035209   |  price: RMSE=58.840088, lin=70.917225, exp=72.020202
# [test     ]  y: RMSE=0.031358, lin=0.031077, exp=0.030079   |  price: RMSE=224.745382, lin=271.767529, exp=280.127076
#
# === NVDA transform 'log_return' (degree=1) ===
# Variance: 9.324989e-04
# --- TRAIN / VAL / TEST metrics (transform vs price) ---
# [train    ]  y: RMSE=0.028420, lin=0.030038, exp=0.029775   |  price: RMSE=1.610690, lin=1.751356, exp=1.681208
# [val      ]  y: RMSE=0.035506, lin=0.035307, exp=0.034452   |  price: RMSE=14.410187, lin=16.436486, exp=15.959635
# [test     ]  y: RMSE=0.031287, lin=0.031068, exp=0.030052   |  price: RMSE=19.033376, lin=18.452237, exp=17.679678
#
# === NVDA transform 'zscore_log_close' (degree=1) ===
# Variance: 1.000000e+00
# --- TRAIN / VAL / TEST metrics (transform vs price) ---
# [train    ]  y: RMSE=0.235038, lin=0.204603, exp=0.199066   |  price: RMSE=1.682348, lin=1.986889, exp=2.020540
# [val      ]  y: RMSE=0.227615, lin=0.218825, exp=0.209756   |  price: RMSE=8.258843, lin=8.306538, exp=8.185273
# [test     ]  y: RMSE=0.342379, lin=0.362653, exp=0.356356   |  price: RMSE=57.685660, lin=66.531457, exp=67.220836
#
# === SUMMARY: test RMSE in TRANSFORM space for each transform ===
# close            | RMSE=108.591444, lin=126.958001, exp=129.033450
# log_close        | RMSE=0.466980, lin=0.490752, exp=0.480235
# sqrt_close       | RMSE=6.096726, lin=6.895719, exp=6.943974
# diff_close       | RMSE=3.697864, lin=4.043686, exp=3.983113
# simple_return    | RMSE=0.031358, lin=0.031077, exp=0.030079
# log_return       | RMSE=0.031287, lin=0.031068, exp=0.030052
# zscore_log_close | RMSE=0.342379, lin=0.362653, exp=0.356356

# %%
# STEP 4 (FIXED). Weighted training vs plain training (plain / linear / exp)

import importlib
import py103

importlib.reload(py103)

from py103 import (
    run_weighted_training_comparison_single_transform,
    plot_weighted_training_comparison,
    compute_price_space_metrics_for_model,
)

# 4A) Run weighted-training comparison for ONE transform (e.g. 'log_close')
wt_results, wt_models, df_wt = run_weighted_training_comparison_single_transform(
    transform_name="log_close",
    ticker="NVDA",
    start="2015-01-01",
    end=None,
    alpha=0.1,
    l1_ratio=0.5,
    random_state=0,
    train_frac=0.6,
    val_frac=0.2,
    ratio_last_first=10.0,   # exp weights: last / first weight ratio
    poly_degree=1,
)

print("\n=== Weighted-training comparison in TRANSFORM and PRICE space ===")
for mode, metrics_y in wt_results.items():
    # metrics_y is a dict by split: 'train', 'val', 'test', 'train_val'
    m_y_val = metrics_y["val"]

    # Compute PRICE-space metrics for this mode/model
    price_metrics = compute_price_space_metrics_for_model(
        df=df_wt,
        model=wt_models[mode],
        transform_name="log_close",
        train_frac=0.6,
        val_frac=0.2,
        ratio_last_first=10.0,
    )
    m_p_val = price_metrics["val"]

    print(
        f"Mode={mode:6s} | "
        f"y_val: RMSE={m_y_val['rmse']:.6f}, "
        f"lin={m_y_val['rmse_w_linear']:.6f}, "
        f"exp={m_y_val['rmse_w_exp']:.6f}   ||   "
        f"price_val: RMSE={m_p_val['rmse']:.6f}, "
        f"lin={m_p_val['rmse_w_linear']:.6f}, "
        f"exp={m_p_val['rmse_w_exp']:.6f}"
    )

# 4B) Plot the three training schemes together (transform + price panels)
plot_weighted_training_comparison(
    df=df_wt,
    models_by_mode=wt_models,
    transform_name="log_close",
    train_frac=0.6,
    val_frac=0.2,
)
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\103 different weighted\py103.py:31: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, progress=False)
# === Weighted-training comparison for transform 'log_close' (degree=1) ===
# Alpha=0.1000, l1_ratio=0.50, ratio_last_first=10.0
# [mode=plain ]  VAL y: RMSE=0.395646, lin=0.397221, exp=0.375377   |  VAL price: RMSE=8.759559, lin=9.001509, exp=8.638061
# [mode=linear]  VAL y: RMSE=0.382586, lin=0.350279, exp=0.359162   |  VAL price: RMSE=9.022410, lin=9.610395, exp=10.172564
# [mode=exp   ]  VAL y: RMSE=0.366483, lin=0.343919, exp=0.336861   |  VAL price: RMSE=8.225706, lin=8.405513, exp=8.565215
#
# === Weighted-training comparison in TRANSFORM and PRICE space ===
# Mode=plain  | y_val: RMSE=0.395646, lin=0.397221, exp=0.375377   ||   price_val: RMSE=8.759559, lin=9.001509, exp=8.638061
# Mode=linear | y_val: RMSE=0.382586, lin=0.350279, exp=0.359162   ||   price_val: RMSE=9.022410, lin=9.610395, exp=10.172564
# Mode=exp    | y_val: RMSE=0.366483, lin=0.343919, exp=0.336861   ||   price_val: RMSE=8.225706, lin=8.405513, exp=8.565215

# %%
# STEP 5. Residual diagnostics on the VALIDATION set (normality etc.)

# Here we reuse the log_model from STEP 2.
# You can also plug in any model from all_models or wt_models.

# 5A) Get validation residuals in transform & price space
res_val = compute_validation_residuals_transform_and_price(
    df=df_nvda,
    model=log_model,
    transform_name="log_close",
    train_frac=0.6,
    val_frac=0.2,
)

resid_y_val = res_val["resid_y_val"]
resid_p_val = res_val["resid_p_val"]

print("Validation residuals (transform space) length:", resid_y_val.shape[0])
print("Validation residuals (price space) length:", resid_p_val.shape[0])

# 5B) Compute normality diagnostics (Jarque-Bera etc.) for price residuals
stats_price = compute_normality_stats(resid_p_val)
print("\n=== Normality stats (price-space validation residuals) ===")
for k, v in stats_price.items():
    print(f"{k:12s} : {v:.6f}" if isinstance(v, float) else f"{k:12s} : {v}")

# 5C) Full residual diagnostic plots (hist, QQ, residuals vs fitted/date)
#     space='transform' or 'price'
plot_validation_residual_diagnostics(
    df=df_nvda,
    model=log_model,
    transform_name="log_close",
    space="price",       # or "transform"
    train_frac=0.6,
    val_frac=0.2,
)
# Out:
# Validation residuals (transform space) length: 548
# Validation residuals (price space) length: 548
#
# === Normality stats (price-space validation residuals) ===
# n            : 548
# mean         : -2.266839
# std          : 8.468896
# skew         : -0.007013
# kurt_excess  : -1.273496
# jb_stat      : 36.996972
# jb_pvalue    : 0.000000
#
# === Validation residual diagnostics (price, transform='log_close') ===
# n = 548
# mean(resid) = -2.266839e+00
# std(resid)  = 8.468896e+00
# t-stat (H0: mean=0) = -6.2659,  p-value = 0.0000
# skewness = -0.0070,  excess kurtosis = -1.2735

# %%
# STEP 6. Normality-regularized model selection
#         (jointly optimizing RMSE + residual normality)

best_summary, best_model, all_candidates, df_norm = (
    run_normality_regularized_model_single_transform(
        transform_name="log_close",
        ticker="NVDA",
        start="2015-01-01",
        end=None,
        alpha_grid=(0.01, 0.1, 1.0),
        l1_ratio_grid=(0.1, 0.5, 0.9),
        poly_degree_grid=(1, 2, 3),
        train_weight_modes=("plain", "linear", "exp"),
        train_frac=0.6,
        val_frac=0.2,
        random_state=0,
        ratio_last_first=10.0,
        w_rmse=1.0,        # weight on validation RMSE in price space
        w_jb=1.0,          # weight on Jarque-Bera statistic
        normality_space="price",  # or "transform"
    )
)

print("\n=== BEST CONFIG (RMSE + normality) ===")
for k, v in best_summary.items():
    print(f"{k:18s} : {v}")

# Optionally, inspect some candidate configs:
print("\nNumber of candidate models:", len(all_candidates))
some_key = next(iter(all_candidates.keys()))
print("\nExample candidate:", some_key)
for k, v in all_candidates[some_key].items():
    print(f"  {k:18s} : {v}")

# Plot diagnostics for the best_model in price space
plot_destransformed_price_trend(
    df=df_norm,
    model=best_model,
    transform_name="log_close",
    train_frac=0.6,
    val_frac=0.2,
)

plot_validation_residual_diagnostics(
    df=df_norm,
    model=best_model,
    transform_name="log_close",
    space="price",
    train_frac=0.6,
    val_frac=0.2,
)
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\103 different weighted\py103.py:31: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, progress=False)
# === Normality-regularized model selection for transform 'log_close' (normality_space=price) ===
# Grids: alpha=[0.01, 0.1, 1.0], l1_ratio=[0.1, 0.5, 0.9], degree=[1, 2, 3], weights=['plain', 'linear', 'exp']
# Objective: obj = 1.0 * RMSE_val_price + 1.0 * JB_stat
#
# alpha=0.01, l1=0.10, deg=1, wmode=plain       | VAL price RMSE=12.709470 | JB=36.538, p=0.000 | obj=49.247812
# alpha=0.01, l1=0.10, deg=1, wmode=linear      | VAL price RMSE=8.291112 | JB=38.688, p=0.000 | obj=46.978710
# alpha=0.01, l1=0.10, deg=1, wmode=exp         | VAL price RMSE=9.227537 | JB=36.222, p=0.000 | obj=45.449227
# alpha=0.01, l1=0.10, deg=2, wmode=plain       | VAL price RMSE=10.932973 | JB=34.646, p=0.000 | obj=45.578717
# alpha=0.01, l1=0.10, deg=2, wmode=linear      | VAL price RMSE=8.398259 | JB=38.259, p=0.000 | obj=46.657679
# alpha=0.01, l1=0.10, deg=2, wmode=exp         | VAL price RMSE=8.711873 | JB=38.130, p=0.000 | obj=46.841572
# alpha=0.01, l1=0.10, deg=3, wmode=plain       | VAL price RMSE=12.985245 | JB=64.774, p=0.000 | obj=77.758900
# alpha=0.01, l1=0.10, deg=3, wmode=linear      | VAL price RMSE=10.040839 | JB=33.711, p=0.000 | obj=43.751437
# alpha=0.01, l1=0.10, deg=3, wmode=exp         | VAL price RMSE=9.267740 | JB=35.468, p=0.000 | obj=44.735527
# alpha=0.01, l1=0.50, deg=1, wmode=plain       | VAL price RMSE=12.702583 | JB=36.527, p=0.000 | obj=49.229879
# alpha=0.01, l1=0.50, deg=1, wmode=linear      | VAL price RMSE=8.282537 | JB=38.698, p=0.000 | obj=46.980673
# alpha=0.01, l1=0.50, deg=1, wmode=exp         | VAL price RMSE=9.213812 | JB=36.250, p=0.000 | obj=45.464194
# alpha=0.01, l1=0.50, deg=2, wmode=plain       | VAL price RMSE=10.715493 | JB=32.818, p=0.000 | obj=43.533981
# alpha=0.01, l1=0.50, deg=2, wmode=linear      | VAL price RMSE=8.282537 | JB=38.698, p=0.000 | obj=46.980673
# alpha=0.01, l1=0.50, deg=2, wmode=exp         | VAL price RMSE=9.213812 | JB=36.250, p=0.000 | obj=45.464194
# alpha=0.01, l1=0.50, deg=3, wmode=plain       | VAL price RMSE=12.619125 | JB=60.117, p=0.000 | obj=72.736043
# alpha=0.01, l1=0.50, deg=3, wmode=linear      | VAL price RMSE=8.874713 | JB=35.641, p=0.000 | obj=44.515332
# alpha=0.01, l1=0.50, deg=3, wmode=exp         | VAL price RMSE=9.213812 | JB=36.250, p=0.000 | obj=45.464194
# alpha=0.01, l1=0.90, deg=1, wmode=plain       | VAL price RMSE=12.695645 | JB=36.516, p=0.000 | obj=49.211841
# alpha=0.01, l1=0.90, deg=1, wmode=linear      | VAL price RMSE=8.274192 | JB=38.707, p=0.000 | obj=46.981367
# alpha=0.01, l1=0.90, deg=1, wmode=exp         | VAL price RMSE=9.200038 | JB=36.279, p=0.000 | obj=45.479494
# alpha=0.01, l1=0.90, deg=2, wmode=plain       | VAL price RMSE=10.479958 | JB=31.011, p=0.000 | obj=41.490614
# alpha=0.01, l1=0.90, deg=2, wmode=linear      | VAL price RMSE=8.274192 | JB=38.707, p=0.000 | obj=46.981367
# alpha=0.01, l1=0.90, deg=2, wmode=exp         | VAL price RMSE=9.200038 | JB=36.279, p=0.000 | obj=45.479494
# alpha=0.01, l1=0.90, deg=3, wmode=plain       | VAL price RMSE=12.805033 | JB=65.384, p=0.000 | obj=78.188686
# alpha=0.01, l1=0.90, deg=3, wmode=linear      | VAL price RMSE=8.339126 | JB=38.411, p=0.000 | obj=46.749945
# alpha=0.01, l1=0.90, deg=3, wmode=exp         | VAL price RMSE=9.200038 | JB=36.279, p=0.000 | obj=45.479494
# alpha=0.1, l1=0.10, deg=1, wmode=plain        | VAL price RMSE=8.864183 | JB=36.739, p=0.000 | obj=45.602739
# alpha=0.1, l1=0.10, deg=1, wmode=linear       | VAL price RMSE=8.777936 | JB=32.690, p=0.000 | obj=41.468039
# alpha=0.1, l1=0.10, deg=1, wmode=exp          | VAL price RMSE=8.190118 | JB=38.085, p=0.000 | obj=46.275250
# alpha=0.1, l1=0.10, deg=2, wmode=plain        | VAL price RMSE=13.696204 | JB=42.691, p=0.000 | obj=56.387070
# alpha=0.1, l1=0.10, deg=2, wmode=linear       | VAL price RMSE=11.574190 | JB=38.886, p=0.000 | obj=50.460512
# alpha=0.1, l1=0.10, deg=2, wmode=exp          | VAL price RMSE=14.220301 | JB=48.065, p=0.000 | obj=62.284889
# alpha=0.1, l1=0.10, deg=3, wmode=plain        | VAL price RMSE=13.696204 | JB=42.691, p=0.000 | obj=56.387070
# alpha=0.1, l1=0.10, deg=3, wmode=linear       | VAL price RMSE=21.009093 | JB=57.928, p=0.000 | obj=78.937517
# alpha=0.1, l1=0.10, deg=3, wmode=exp          | VAL price RMSE=21.666236 | JB=58.804, p=0.000 | obj=80.469777
# alpha=0.1, l1=0.50, deg=1, wmode=plain        | VAL price RMSE=8.759560 | JB=36.997, p=0.000 | obj=45.756526
# alpha=0.1, l1=0.50, deg=1, wmode=linear       | VAL price RMSE=9.022410 | JB=31.162, p=0.000 | obj=40.184848
# alpha=0.1, l1=0.50, deg=1, wmode=exp          | VAL price RMSE=8.225706 | JB=37.602, p=0.000 | obj=45.827482
# alpha=0.1, l1=0.50, deg=2, wmode=plain        | VAL price RMSE=8.759560 | JB=36.997, p=0.000 | obj=45.756526
# alpha=0.1, l1=0.50, deg=2, wmode=linear       | VAL price RMSE=9.755605 | JB=33.653, p=0.000 | obj=43.408859
# alpha=0.1, l1=0.50, deg=2, wmode=exp          | VAL price RMSE=11.162065 | JB=36.743, p=0.000 | obj=47.904690
# alpha=0.1, l1=0.50, deg=3, wmode=plain        | VAL price RMSE=8.759560 | JB=36.997, p=0.000 | obj=45.756526
# alpha=0.1, l1=0.50, deg=3, wmode=linear       | VAL price RMSE=15.662606 | JB=56.481, p=0.000 | obj=72.143184
# alpha=0.1, l1=0.50, deg=3, wmode=exp          | VAL price RMSE=14.474974 | JB=51.193, p=0.000 | obj=65.668002
# alpha=0.1, l1=0.90, deg=1, wmode=plain        | VAL price RMSE=8.656925 | JB=37.268, p=0.000 | obj=45.924536
# alpha=0.1, l1=0.90, deg=1, wmode=linear       | VAL price RMSE=9.326397 | JB=29.563, p=0.000 | obj=38.889688
# alpha=0.1, l1=0.90, deg=1, wmode=exp          | VAL price RMSE=8.289861 | JB=36.924, p=0.000 | obj=45.213485
# alpha=0.1, l1=0.90, deg=2, wmode=plain        | VAL price RMSE=8.656925 | JB=37.268, p=0.000 | obj=45.924536
# alpha=0.1, l1=0.90, deg=2, wmode=linear       | VAL price RMSE=8.473584 | JB=34.294, p=0.000 | obj=42.767742
# alpha=0.1, l1=0.90, deg=2, wmode=exp          | VAL price RMSE=8.221272 | JB=37.957, p=0.000 | obj=46.177987
# alpha=0.1, l1=0.90, deg=3, wmode=plain        | VAL price RMSE=8.656925 | JB=37.268, p=0.000 | obj=45.924536
# alpha=0.1, l1=0.90, deg=3, wmode=linear       | VAL price RMSE=11.831317 | JB=45.221, p=0.000 | obj=57.052132
# alpha=0.1, l1=0.90, deg=3, wmode=exp          | VAL price RMSE=9.027498 | JB=33.290, p=0.000 | obj=42.317236
# alpha=1, l1=0.10, deg=1, wmode=plain          | VAL price RMSE=17.207584 | JB=51.947, p=0.000 | obj=69.154148
# alpha=1, l1=0.10, deg=1, wmode=linear         | VAL price RMSE=17.356750 | JB=66.377, p=0.000 | obj=83.733255
# alpha=1, l1=0.10, deg=1, wmode=exp            | VAL price RMSE=16.280440 | JB=56.745, p=0.000 | obj=73.025768
# alpha=1, l1=0.10, deg=2, wmode=plain          | VAL price RMSE=10.193991 | JB=34.017, p=0.000 | obj=44.210710
# alpha=1, l1=0.10, deg=2, wmode=linear         | VAL price RMSE=12.136411 | JB=26.224, p=0.000 | obj=38.360712
# alpha=1, l1=0.10, deg=2, wmode=exp            | VAL price RMSE=10.207342 | JB=30.322, p=0.000 | obj=40.529782
# alpha=1, l1=0.10, deg=3, wmode=plain          | VAL price RMSE=11.242636 | JB=49.301, p=0.000 | obj=60.543358
# alpha=1, l1=0.10, deg=3, wmode=linear         | VAL price RMSE=8.423691 | JB=30.922, p=0.000 | obj=39.345918
# alpha=1, l1=0.10, deg=3, wmode=exp            | VAL price RMSE=11.003267 | JB=46.478, p=0.000 | obj=57.481617
# alpha=1, l1=0.50, deg=1, wmode=plain          | VAL price RMSE=19.787518 | JB=72.201, p=0.000 | obj=91.989016
# alpha=1, l1=0.50, deg=1, wmode=linear         | VAL price RMSE=20.459666 | JB=90.908, p=0.000 | obj=111.367394
# alpha=1, l1=0.50, deg=1, wmode=exp            | VAL price RMSE=19.190547 | JB=81.814, p=0.000 | obj=101.004117
# alpha=1, l1=0.50, deg=2, wmode=plain          | VAL price RMSE=18.114079 | JB=53.730, p=0.000 | obj=71.844447
# alpha=1, l1=0.50, deg=2, wmode=linear         | VAL price RMSE=19.075947 | JB=76.794, p=0.000 | obj=95.870401
# alpha=1, l1=0.50, deg=2, wmode=exp            | VAL price RMSE=17.058340 | JB=57.030, p=0.000 | obj=74.088622
# alpha=1, l1=0.50, deg=3, wmode=plain          | VAL price RMSE=18.069186 | JB=53.158, p=0.000 | obj=71.227037
# alpha=1, l1=0.50, deg=3, wmode=linear         | VAL price RMSE=17.259950 | JB=52.688, p=0.000 | obj=69.947750
# alpha=1, l1=0.50, deg=3, wmode=exp            | VAL price RMSE=14.140791 | JB=28.137, p=0.000 | obj=42.278248
# alpha=1, l1=0.90, deg=1, wmode=plain          | VAL price RMSE=22.652588 | JB=91.262, p=0.000 | obj=113.914519
# alpha=1, l1=0.90, deg=1, wmode=linear         | VAL price RMSE=20.976208 | JB=94.207, p=0.000 | obj=115.182997
# alpha=1, l1=0.90, deg=1, wmode=exp            | VAL price RMSE=20.929766 | JB=94.207, p=0.000 | obj=115.136554
# alpha=1, l1=0.90, deg=2, wmode=plain          | VAL price RMSE=22.652588 | JB=91.262, p=0.000 | obj=113.914519
# alpha=1, l1=0.90, deg=2, wmode=linear         | VAL price RMSE=20.976208 | JB=94.207, p=0.000 | obj=115.182997
# alpha=1, l1=0.90, deg=2, wmode=exp            | VAL price RMSE=20.929766 | JB=94.207, p=0.000 | obj=115.136554
# alpha=1, l1=0.90, deg=3, wmode=plain          | VAL price RMSE=22.652588 | JB=91.262, p=0.000 | obj=113.914519
# alpha=1, l1=0.90, deg=3, wmode=linear         | VAL price RMSE=20.976208 | JB=94.207, p=0.000 | obj=115.182997
# alpha=1, l1=0.90, deg=3, wmode=exp            | VAL price RMSE=20.929766 | JB=94.207, p=0.000 | obj=115.136554
#
# === BEST MODEL (smallest objective) ===
# alpha=1, l1=0.10, degree=2, weight_mode=linear
# VAL price RMSE=12.136411, JB=26.224, p=0.000, objective=38.360712
#
# === BEST CONFIG (RMSE + normality) ===
# transform_name     : log_close
# alpha              : 1.0
# l1_ratio           : 0.1
# poly_degree        : 2
# weight_mode        : linear
# metrics_y          : {'train': {'rmse': 0.7854310805224988, 'rmse_w_linear': 0.4715304610834264, 'rmse_w_exp': 0.5384129066629119}, 'val': {'rmse': 0.5421596626991335, 'rmse_w_linear': 0.49269428226561474, 'rmse_w_exp': 0.522763755912101}, 'test': {'rmse': 1.1278922566178513, 'rmse_w_linear': 1.180519707561524, 'rmse_w_exp': 1.1680457289154147}, 'train_val': {'rmse': 0.732280249286088, 'rmse_w_linear': 0.5004356198712822, 'rmse_w_exp': 0.5613479492564968}}
# metrics_price      : {'train': {'rmse': 2.5678505533572356, 'rmse_w_linear': 3.1197634605531848, 'rmse_w_exp': 3.3671257774242003}, 'val': {'rmse': 12.136410566186624, 'rmse_w_linear': 13.30773902622902, 'rmse_w_exp': 14.265905429926972}, 'test': {'rmse': 87.53172928076901, 'rmse_w_linear': 101.34271878641948, 'rmse_w_exp': 102.6496657949359}, 'train_val': {'rmse': 6.46037485769947, 'rmse_w_linear': 8.468666568668386, 'rmse_w_exp': 9.035038480978137}}
# rmse_val_price     : 12.136410566186624
# normality_space    : price
# normality_stats    : {'n': 548, 'mean': 8.993640152453374, 'std': 8.156488230051874, 'skew': 0.330494014651763, 'kurt_excess': -0.8417134122682204, 'jb_stat': 26.22430180201563, 'jb_pvalue': 2.0205296034111116e-06}
# objective          : 38.36071236820226
#
# Number of candidate models: 81
#
# Example candidate: candidate_1
#   transform_name     : log_close
#   alpha              : 0.01
#   l1_ratio           : 0.1
#   poly_degree        : 1
#   weight_mode        : plain
#   metrics_y          : {'train': {'rmse': 0.3684945876410682, 'rmse_w_linear': 0.34797874024952213, 'rmse_w_exp': 0.3291488436223491}, 'val': {'rmse': 0.4991682262917815, 'rmse_w_linear': 0.5400742410262346, 'rmse_w_exp': 0.5086055100798}, 'test': {'rmse': 0.238031894093562, 'rmse_w_linear': 0.21902751467071102, 'rmse_w_exp': 0.21155222920898079}, 'train_val': {'rmse': 0.4051019459034907, 'rmse_w_linear': 0.42393996817520246, 'rmse_w_exp': 0.4311305253251375}}
#   metrics_price      : {'train': {'rmse': 1.5792816906049558, 'rmse_w_linear': 1.771230295533668, 'rmse_w_exp': 1.717115817185291}, 'val': {'rmse': 12.709470160132444, 'rmse_w_linear': 14.222049516198101, 'rmse_w_exp': 13.661027784715582}, 'test': {'rmse': 25.7864382457768, 'rmse_w_linear': 27.087100147949155, 'rmse_w_exp': 26.52009331882736}, 'train_val': {'rmse': 6.49746199883243, 'rmse_w_linear': 8.655144394510843, 'rmse_w_exp': 9.226419307464328}}
#   rmse_val_price     : 12.709470160132444
#   normality_space    : price
#   normality_stats    : {'n': 548, 'mean': -8.33438754387489, 'std': 9.604006017719483, 'skew': 0.20132874571189016, 'kurt_excess': -1.1995601581362108, 'jb_stat': 36.538341979599316, 'jb_pvalue': 1.1635896515854707e-08}
#   objective          : 49.247812139731764
# === Validation residual diagnostics (price, transform='log_close') ===
# n = 548
# mean(resid) = 8.993640e+00
# std(resid)  = 8.156488e+00
# t-stat (H0: mean=0) = 25.8121,  p-value = 0.0000
# skewness = 0.3305,  excess kurtosis = -0.8417
