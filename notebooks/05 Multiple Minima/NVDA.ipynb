# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '05 Multiple Minima'))

# %%
from scripts import style
importlib.reload(style)
style.set_style()

# %%
import py_10_multiple_minima as py10
importlib.reload(py10)
py10.main(ticker="NVDA", start="2010-01-01", save_pdf_path="figuras/py10")
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded NVDA from 2010-01-04 to 2025-11-28 (N=4002, log=True).
# Train length = 2401, val = 800, test = 801.
#
# === Building spectral solver for d=2 ===
#
# === Finding all local minima in s for d=2 ===
#
# [d=2] found 6 local minima on [0.001,0.999]:
#   s≈0.118628, J(s)≈3.800517e-02
#   s≈0.630713, J(s)≈2.207788e+00
#   s≈0.925665, J(s)≈4.733311e+00
#   s≈0.975504, J(s)≈1.221232e-01
#   s≈0.990943, J(s)≈1.279552e+00
#   s≈0.998943, J(s)≈9.209660e-02
# --- Plotting train/val/test for d=2, local minimum 1/6, s≈0.1186, val_MSE≈3.800517e-02 ---
# --- Plotting train/val/test for d=2, local minimum 2/6, s≈0.6307, val_MSE≈2.207788e+00 ---
# ...
