# %%
# for this notebook make the path in the same folder (currently is in the project folder)
import os
import sys
import importlib

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '05 Multiple Minima'))

# %%
import py_10_multiple_minima as py10
importlib.reload(py10)
py10.main()
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:307: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded NVDA from 2010-01-04 to 2025-11-25 (N=4000, log=True).
# Train length = 2400, val = 800, test = 800.
#
# === Building spectral solver for d=1 ===
#
# === Building spectral solver for d=2 ===
#
# === Building spectral solver for d=3 ===
#
# === Building spectral solver for d=4 ===
#
# === Finding all local minima in s for d=1 ===
#
# [d=1] found 2 local minima on [0.001,0.999]:
#   s≈0.001000, J(s)≈6.442594e-01
#   s≈0.998677, J(s)≈1.903048e-01
# === Finding all local minima in s for d=2 ===
#
# [d=2] found 5 local minima on [0.001,0.999]:
#   s≈0.628648, J(s)≈3.209873e+00
#   s≈0.921549, J(s)≈4.196560e+00
#   s≈0.974761, J(s)≈1.227055e-01
#   s≈0.990981, J(s)≈1.345725e+00
#   s≈0.998941, J(s)≈9.181417e-02
# === Finding all local minima in s for d=3 ===
#
# [d=3] found 7 local minima on [0.001,0.999]:
#   s≈0.659995, J(s)≈3.955812e+02
#   s≈0.803555, J(s)≈6.886864e+01
#   s≈0.923757, J(s)≈3.677694e-02
#   s≈0.955176, J(s)≈2.551225e+00
#   s≈0.984625, J(s)≈1.062442e+00
#   s≈0.990773, J(s)≈4.087836e-01
#   s≈0.995415, J(s)≈3.584701e-01
# === Finding all local minima in s for d=4 ===
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:113: RuntimeWarning: divide by zero encountered in divide
#   trAinv = np.sum(1.0 / denom)
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:174: RuntimeWarning: divide by zero encountered in divide
#   z = y / denom                               # elementwise
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:175: RuntimeWarning: invalid value encountered in matmul
#   t_hat = Q @ z                               # back to original basis
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:177: RuntimeWarning: invalid value encountered in matmul
#   m_new = float(np.mean(K @ t_hat))
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:184: RuntimeWarning: divide by zero encountered in divide
#   alpha = 1.0 / (1.0 + lam * eigvals)
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:186: RuntimeWarning: invalid value encountered in matmul
#   diag_Ainv = (Q ** 2) @ alpha
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\05 Multiple Minima\py_10_multiple_minima.py:174: RuntimeWarning: overflow encountered in divide
#   z = y / denom                               # elementwise
# [d=4] found 7 local minima on [0.001,0.999]:
#   s≈0.201026, J(s)≈2.809675e+11
#   s≈0.716767, J(s)≈7.338908e+05
#   s≈0.851543, J(s)≈1.055982e+05
#   s≈0.936676, J(s)≈6.609345e+01
#   s≈0.968214, J(s)≈1.308299e+02
#   s≈0.987085, J(s)≈2.405586e+01
#   s≈0.993997, J(s)≈nan
# --- Plotting train/val/test for d=1, local minimum 1/2, s≈0.0010, val_MSE≈6.442594e-01 ---
# --- Plotting train/val/test for d=1, local minimum 2/2, s≈0.9987, val_MSE≈1.903048e-01 ---
# --- Plotting train/val/test for d=2, local minimum 1/5, s≈0.6286, val_MSE≈3.209873e+00 ---
# --- Plotting train/val/test for d=2, local minimum 2/5, s≈0.9215, val_MSE≈4.196560e+00 ---
# --- Plotting train/val/test for d=2, local minimum 3/5, s≈0.9748, val_MSE≈1.227055e-01 ---
# --- Plotting train/val/test for d=2, local minimum 4/5, s≈0.9910, val_MSE≈1.345725e+00 ---
# --- Plotting train/val/test for d=2, local minimum 5/5, s≈0.9989, val_MSE≈9.181417e-02 ---
# --- Plotting train/val/test for d=3, local minimum 1/7, s≈0.6600, val_MSE≈3.955812e+02 ---
# --- Plotting train/val/test for d=3, local minimum 2/7, s≈0.8036, val_MSE≈6.886864e+01 ---
# --- Plotting train/val/test for d=3, local minimum 3/7, s≈0.9238, val_MSE≈3.677694e-02 ---
# --- Plotting train/val/test for d=3, local minimum 4/7, s≈0.9552, val_MSE≈2.551225e+00 ---
# --- Plotting train/val/test for d=3, local minimum 5/7, s≈0.9846, val_MSE≈1.062442e+00 ---
# --- Plotting train/val/test for d=3, local minimum 6/7, s≈0.9908, val_MSE≈4.087836e-01 ---
# --- Plotting train/val/test for d=3, local minimum 7/7, s≈0.9954, val_MSE≈3.584701e-01 ---
# --- Plotting train/val/test for d=4, local minimum 1/7, s≈0.2010, val_MSE≈2.809675e+11 ---
# --- Plotting train/val/test for d=4, local minimum 2/7, s≈0.7168, val_MSE≈7.338908e+05 ---
# --- Plotting train/val/test for d=4, local minimum 3/7, s≈0.8515, val_MSE≈1.055982e+05 ---
# --- Plotting train/val/test for d=4, local minimum 4/7, s≈0.9367, val_MSE≈6.609345e+01 ---
# --- Plotting train/val/test for d=4, local minimum 5/7, s≈0.9682, val_MSE≈1.308299e+02 ---
# --- Plotting train/val/test for d=4, local minimum 6/7, s≈0.9871, val_MSE≈2.405586e+01 ---

# %%
2**2 + 3**2 + 4**2+  2**2 + 2**2 + 1**2
# Out:
# 38
