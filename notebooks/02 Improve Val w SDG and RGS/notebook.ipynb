# %% [markdown]
# # Improve in the validation set

# %%
import os
import sys

# Add the path to the val03 folder to sys.path so modules in the same folder can be imported
sys.path.append(os.path.join('notebooks', '02 Improve Val w SDG and RGS'))

# %% [markdown]
# # 07 SGD more than 2 differences

# %%
import py_07_SDG_more_diffs_all_plots as s07
import importlib
importlib.reload(s07)
s07.main()
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\02 Improve Val w SDG and RGS\py_07_SDG_more_diffs_all_plots.py:271: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)

# %%
import py_07_SDG_more_diffs_all_plots as s07
import importlib
importlib.reload(s07)
s07.main()
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\val\py_07_SDG_more_diffs_all_plots.py:271: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded ^GSPC from 2010-01-04 to 2025-11-25 (N=4000, log=True).
# Train length = 2400, val = 800, test = 800.
#
# === Optimizing s for d=1 (SGD-style) ===
# [d=1] iter=00 | s=0.3000 | approx_MSE=1.281842e-02 | grad≈-6.940e-04
# [d=1] iter=01 | s=0.3001 | approx_MSE=1.343671e-02 | grad≈-7.173e-04
# [d=1] iter=02 | s=0.3003 | approx_MSE=1.292920e-02 | grad≈-6.083e-04
# [d=1] iter=03 | s=0.3004 | approx_MSE=1.397028e-02 | grad≈-6.557e-04
# [d=1] iter=04 | s=0.3005 | approx_MSE=1.340152e-02 | grad≈-6.208e-04
# [d=1] iter=05 | s=0.3007 | approx_MSE=1.300417e-02 | grad≈-5.709e-04
# [d=1] iter=06 | s=0.3008 | approx_MSE=1.355831e-02 | grad≈-6.576e-04
# ...

# %% [markdown]
# # 06 More Differences

# %%
import py_06_SDG_more_diffs as s06
import importlib
importlib.reload(s06)
s06.main()
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\val\py_06_SDG_more_diffs.py:288: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded ^GSPC from 2010-01-04 to 2025-11-25 (N=4000, log=True).
# Train length = 2400, val = 800, test = 800.
#
# === Optimizing s for d=1 (SGD-style) ===
# d=1: best s≈0.8004, val_MSE≈0.012615
#
# === Optimizing s for d=2 (SGD-style) ===
# d=2: best s≈0.9990, val_MSE≈0.020194
#
# === Optimizing s for d=3 (SGD-style) ===
# d=3: best s≈0.0010, val_MSE≈213539.948969
#
# === Optimizing s for d=4 (SGD-style) ===
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\val\py_06_SDG_more_diffs.py:177: RuntimeWarning: overflow encountered in multiply
#   t_hat = Ainv @ (Z + lam * m * K1)
# ...

# %% [markdown]
# # 05 SDG

# %%
import py_05_SDG as s05
import importlib
importlib.reload(s05)
s05.main()
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\val\py_05_SDG.py:250: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded ^GSPC from 2010-01-04 to 2025-11-25 (N=4000, log=True).
# Train length = 2400, val = 800, test = 800.
#
# === Optimizing s for d=1 (SGD-style) ===
# d=1: best s≈0.8004, val_MSE≈0.012615
#
# === Optimizing s for d=2 (SGD-style) ===
# d=2: best s≈0.9990, val_MSE≈0.020194
#
# Best hyperparameters by validation MSE: d*=1, s*≈0.8004, val_MSE≈0.012615

# %% [markdown]
# # 04 Simple Grid Search Validation

# %%
import py_04_Simple_grid_search as s04
s04.main()
# Out:
# c:\Users\herie\GitHub\Proyectos\En Pausa\Estimacion de Tendencia\notebooks\val\py_04_Simple_grid_search.py:248: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Loaded ^GSPC from 2010-01-04 to 2025-11-25 (N=4000, log=True).
# Train length = 2400, val = 800, test = 800.
#
# === Evaluating config d1_s0.30 (d=1, s=0.300, GPU=False) ===
#   -> s_real≈0.3000, λ≈0.26, RMSE_train=0.00205, RMSE_val=0.11397
#
# === Evaluating config d1_s0.90 (d=1, s=0.900, GPU=False) ===
#   -> s_real≈0.9000, λ≈24.7, RMSE_train=0.01009, RMSE_val=0.11281
#
# === Evaluating config d1_s0.98 (d=1, s=0.980, GPU=False) ===
#   -> s_real≈0.9800, λ≈612, RMSE_train=0.02048, RMSE_val=0.11972
#
# === Evaluating config d2_s0.30 (d=2, s=0.300, GPU=False) ===
#   -> s_real≈0.3000, λ≈0.106, RMSE_train=0.00206, RMSE_val=3.58191
#
# ...
